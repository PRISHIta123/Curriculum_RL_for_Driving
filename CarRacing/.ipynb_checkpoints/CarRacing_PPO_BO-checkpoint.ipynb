# %% [markdown]
# **1. Import Dependencies**

# %%
import os
import numpy as np
import pandas as pd
import time

# %%
import gym
from stable_baselines3 import PPO      #PPO -> Proximal Policy Optimization
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy  #to evaluate the model 
from stable_baselines3.common.callbacks import EvalCallback

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1024, 768))
display.start()


from matplotlib import pyplot as plt, animation
# %matplotlib inline
from IPython import display

def create_anim(frames, dpi, fps):
    plt.figure(figsize=(frames[0].shape[1] / dpi, frames[0].shape[0] / dpi), dpi=dpi)
    patch = plt.imshow(frames[0])
    def setup():
        plt.axis('off')
    def animate(i):
        patch.set_data(frames[i])
    anim = animation.FuncAnimation(plt.gcf(), animate, init_func=setup, frames=len(frames), interval=fps)
    return anim

def display_anim(frames, dpi=72, fps=60):
    anim = create_anim(frames, dpi, fps)
    return anim.to_jshtml()

def save_anim(frames, filename, dpi=72, fps=50):
    anim = create_anim(frames, dpi, fps)
    anim.save(filename)


class trigger:
    def __init__(self):
        self._trigger = True

    def __call__(self, e):
        return self._trigger

    def set(self, t):
        self._trigger = t

# %% [markdown]
# **2.Train Environment**

# %%
# Default environment
# environment_name = 'CarRacing-v0'    
# env = gym.make(environment_name)
# eval_env= env

# Curriculum environment
from gym.wrappers.time_limit import TimeLimit
from TurnRates.car_racing_curriculum import CarRacingCurriculum
# Best ranges chosen from BO
ranges=np.array([3429,6858,11421])
env = TimeLimit(CarRacingCurriculum(ranges),max_episode_steps=1000)

# Evaluation environment
from gym.wrappers.time_limit import TimeLimit
from TurnRates.car_racing_eval import CarRacingEval
eval_env = TimeLimit(CarRacingEval(),max_episode_steps=1000)

# Default obstacles environment
# from gym.wrappers.time_limit import TimeLimit
# from car_racing_obstacles import CarRacingObstacles
# env = TimeLimit(CarRacingObstacles(),max_episode_steps=1000)
# eval_env= env

# Curriculum obstacles environment
# from gym.wrappers.time_limit import TimeLimit
# from Obstacles.car_racing_obstacles_curriculum import CarRacingObstaclesCurriculum
# env = TimeLimit(CarRacingObstaclesCurriculum(),max_episode_steps=1000)

# Obstacles Evaluation environment
# from gym.wrappers.time_limit import TimeLimit
# from Obstacles.car_racing_obstacles_eval import CarRacingObstaclesEval
# eval_env = TimeLimit(CarRacingObstaclesEval(),max_episode_steps=1000)

# Curriculum both environment
# from gym.wrappers.time_limit import TimeLimit
# from Both.car_racing_obstacles_curriculum_both import CarRacingObstaclesCurriculumBoth
# env = TimeLimit(CarRacingObstaclesCurriculumBoth(),max_episode_steps=1000)

# Evaluation both environment
# from gym.wrappers.time_limit import TimeLimit
# from Both.car_racing_obstacles_eval_both import CarRacingObstaclesEvalBoth
# eval_env = TimeLimit(CarRacingObstaclesEvalBoth(),max_episode_steps=1000)

# %% [markdown]
# **3.Training Model**

# %%
seed=0

# %%
log_path = os.path.join('./runs')

# Learning Rates: 
# 0.0005- PPO Default, 0.00025- PPO Curriculum
# 0.0005- PPO Obstacles, 0.000475- PPO Obstacles Curriculum
# 0.0002- PPO Both Curriculum

model = PPO('CnnPolicy', env, learning_rate=0.00025, n_steps=1000, batch_size=1000, verbose=1, seed=0, tensorboard_log=log_path)
ppo_path = os.path.join('./Training/Saved_Models/PPO_car_best_Model_curriculum')

eval_callback = EvalCallback(eval_env=eval_env, best_model_save_path=ppo_path,
                             n_eval_episodes=10,
                             eval_freq=50000,verbose=1,
                             deterministic=True, render=False)
model.learn(total_timesteps=1000000,callback=eval_callback)
ppo_path = os.path.join('./Training/Saved_Models/PPO_Model_final_curriculum.zip')
model.save(ppo_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to ./runs/PPO_1
# /Users/PrishitaRay1/opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/callbacks.py:399: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x287b3f040> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x287b3fd00>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -59.7    |
# | time/              |          |
# |    fps             | 245      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1000     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -53.2        |
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 2            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 2000         |
# | train/                  |              |
# |    approx_kl            | 0.0052174455 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.000512    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.452        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00274     |
# |    std                  | 0.999        |
# |    value_loss           | 1.48         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -53.1        |
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 3            |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 3000         |
# | train/                  |              |
# |    approx_kl            | 0.0061640665 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.0196       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.452        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00424     |
# |    std                  | 1            |
# |    value_loss           | 1.03         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -55.5       |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 4           |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 4000        |
# | train/                  |             |
# |    approx_kl            | 0.005844652 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.00914     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.399       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00298    |
# |    std                  | 1           |
# |    value_loss           | 0.891       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -56          |
# | time/                   |              |
# |    fps                  | 66           |
# |    iterations           | 5            |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 5000         |
# | train/                  |              |
# |    approx_kl            | 0.0073917136 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.0312       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.332        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0015      |
# |    std                  | 1            |
# |    value_loss           | 0.736        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -56.7        |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 6            |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 6000         |
# | train/                  |              |
# |    approx_kl            | 0.0054940777 |
# |    clip_fraction        | 0.0083       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.0549       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.33         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00108     |
# |    std                  | 0.999        |
# |    value_loss           | 0.753        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -57.7      |
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 7          |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 7000       |
# | train/                  |            |
# |    approx_kl            | 0.00716656 |
# |    clip_fraction        | 0.0238     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.118      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.39       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00178   |
# |    std                  | 0.998      |
# |    value_loss           | 0.881      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -57.9       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 8           |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 8000        |
# | train/                  |             |
# |    approx_kl            | 0.012287785 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.236       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00438    |
# |    std                  | 0.997       |
# |    value_loss           | 0.599       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -55.8        |
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 9            |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 9000         |
# | train/                  |              |
# |    approx_kl            | 0.0045912275 |
# |    clip_fraction        | 0.007        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.565        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.301        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.000423     |
# |    std                  | 0.997        |
# |    value_loss           | 0.703        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -56.5        |
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 10           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0142842205 |
# |    clip_fraction        | 0.0689       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.177        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.628        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00682     |
# |    std                  | 0.997        |
# |    value_loss           | 1.36         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -57.3        |
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 11           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 11000        |
# | train/                  |              |
# |    approx_kl            | 0.0072619445 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.628        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.293        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000981    |
# |    std                  | 0.996        |
# |    value_loss           | 0.614        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -58.8       |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 12          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 12000       |
# | train/                  |             |
# |    approx_kl            | 0.033020917 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.283       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00123    |
# |    std                  | 0.996       |
# |    value_loss           | 0.615       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -59.4       |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 13          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 13000       |
# | train/                  |             |
# |    approx_kl            | 0.010989378 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.119       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00307    |
# |    std                  | 0.995       |
# |    value_loss           | 0.375       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -60.2       |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 14          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 14000       |
# | train/                  |             |
# |    approx_kl            | 0.010496683 |
# |    clip_fraction        | 0.0619      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.243       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00268    |
# |    std                  | 0.995       |
# |    value_loss           | 0.502       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -61.1       |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 15          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 15000       |
# | train/                  |             |
# |    approx_kl            | 0.017658086 |
# |    clip_fraction        | 0.0653      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.176       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00109    |
# |    std                  | 0.994       |
# |    value_loss           | 0.724       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -62          |
# | time/                   |              |
# |    fps                  | 59           |
# |    iterations           | 16           |
# |    time_elapsed         | 269          |
# |    total_timesteps      | 16000        |
# | train/                  |              |
# |    approx_kl            | 0.0060796686 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 0.902        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.13         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 0.995        |
# |    value_loss           | 0.442        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -62.7       |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 17          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 17000       |
# | train/                  |             |
# |    approx_kl            | 0.009012656 |
# |    clip_fraction        | 0.0254      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.117       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00241    |
# |    std                  | 0.995       |
# |    value_loss           | 0.361       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -63.4       |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 18          |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 18000       |
# | train/                  |             |
# |    approx_kl            | 0.015496704 |
# |    clip_fraction        | 0.0623      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.12        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00376    |
# |    std                  | 0.994       |
# |    value_loss           | 0.354       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -64.1        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 19           |
# |    time_elapsed         | 322          |
# |    total_timesteps      | 19000        |
# | train/                  |              |
# |    approx_kl            | 0.0025254148 |
# |    clip_fraction        | 0.0636       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.133        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00568     |
# |    std                  | 0.994        |
# |    value_loss           | 0.375        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -63.5       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 20          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.015570443 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0857      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00383    |
# |    std                  | 0.994       |
# |    value_loss           | 0.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -64.3       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 21          |
# |    time_elapsed         | 358         |
# |    total_timesteps      | 21000       |
# | train/                  |             |
# |    approx_kl            | 0.012609798 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.374       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00938     |
# |    std                  | 0.994       |
# |    value_loss           | 0.934       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -64.8       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 22          |
# |    time_elapsed         | 375         |
# |    total_timesteps      | 22000       |
# | train/                  |             |
# |    approx_kl            | 0.024562942 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0576      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00182    |
# |    std                  | 0.994       |
# |    value_loss           | 0.292       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -65.2       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 23          |
# |    time_elapsed         | 393         |
# |    total_timesteps      | 23000       |
# | train/                  |             |
# |    approx_kl            | 0.026434084 |
# |    clip_fraction        | 0.0677      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.11        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00165    |
# |    std                  | 0.995       |
# |    value_loss           | 0.356       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -64.4       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 24          |
# |    time_elapsed         | 411         |
# |    total_timesteps      | 24000       |
# | train/                  |             |
# |    approx_kl            | 0.005608567 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.242       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000659   |
# |    std                  | 0.995       |
# |    value_loss           | 0.421       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -63.7        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 25           |
# |    time_elapsed         | 429          |
# |    total_timesteps      | 25000        |
# | train/                  |              |
# |    approx_kl            | 0.0034255027 |
# |    clip_fraction        | 0.0546       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 0.92         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.314        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00253     |
# |    std                  | 0.995        |
# |    value_loss           | 0.772        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -64.2       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 26          |
# |    time_elapsed         | 446         |
# |    total_timesteps      | 26000       |
# | train/                  |             |
# |    approx_kl            | 0.015773399 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.412       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00319    |
# |    std                  | 0.995       |
# |    value_loss           | 0.782       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -63.2       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 27          |
# |    time_elapsed         | 464         |
# |    total_timesteps      | 27000       |
# | train/                  |             |
# |    approx_kl            | 0.016529614 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.101       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00466    |
# |    std                  | 0.995       |
# |    value_loss           | 0.291       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -61.4       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 28          |
# |    time_elapsed         | 482         |
# |    total_timesteps      | 28000       |
# | train/                  |             |
# |    approx_kl            | 0.010860919 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.391       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0037     |
# |    std                  | 0.995       |
# |    value_loss           | 0.995       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -59         |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 29          |
# |    time_elapsed         | 499         |
# |    total_timesteps      | 29000       |
# | train/                  |             |
# |    approx_kl            | 0.014723774 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.753       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0033     |
# |    std                  | 0.995       |
# |    value_loss           | 1.91        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -56.8        |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 30           |
# |    time_elapsed         | 517          |
# |    total_timesteps      | 30000        |
# | train/                  |              |
# |    approx_kl            | 0.0072144996 |
# |    clip_fraction        | 0.0652       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 0.72         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.34         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.00629      |
# |    std                  | 0.995        |
# |    value_loss           | 3.77         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53.6       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 31          |
# |    time_elapsed         | 535         |
# |    total_timesteps      | 31000       |
# | train/                  |             |
# |    approx_kl            | 0.008252369 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.88        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00372    |
# |    std                  | 0.995       |
# |    value_loss           | 2.07        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.7       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 32          |
# |    time_elapsed         | 553         |
# |    total_timesteps      | 32000       |
# | train/                  |             |
# |    approx_kl            | 0.005296229 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.578       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00656    |
# |    std                  | 0.994       |
# |    value_loss           | 1.38        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 33          |
# |    time_elapsed         | 570         |
# |    total_timesteps      | 33000       |
# | train/                  |             |
# |    approx_kl            | 0.050814882 |
# |    clip_fraction        | 0.491       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.647       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.0316      |
# |    std                  | 0.994       |
# |    value_loss           | 1.94        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -44.7       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 34          |
# |    time_elapsed         | 588         |
# |    total_timesteps      | 34000       |
# | train/                  |             |
# |    approx_kl            | 0.015160165 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.41        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.0146      |
# |    std                  | 0.994       |
# |    value_loss           | 4.46        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -41.8      |
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 35         |
# |    time_elapsed         | 606        |
# |    total_timesteps      | 35000      |
# | train/                  |            |
# |    approx_kl            | 0.01648202 |
# |    clip_fraction        | 0.281      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.24      |
# |    explained_variance   | 0.791      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 4.11       |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.0101     |
# |    std                  | 0.994      |
# |    value_loss           | 10.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -41.9       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 36          |
# |    time_elapsed         | 623         |
# |    total_timesteps      | 36000       |
# | train/                  |             |
# |    approx_kl            | 0.007214595 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.7         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00378     |
# |    std                  | 0.994       |
# |    value_loss           | 7.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -35.4       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 37          |
# |    time_elapsed         | 641         |
# |    total_timesteps      | 37000       |
# | train/                  |             |
# |    approx_kl            | 0.028876023 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.795       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.000442    |
# |    std                  | 0.993       |
# |    value_loss           | 1.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -33.3       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 38          |
# |    time_elapsed         | 659         |
# |    total_timesteps      | 38000       |
# | train/                  |             |
# |    approx_kl            | 0.018563066 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.61        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00525    |
# |    std                  | 0.993       |
# |    value_loss           | 12.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -30         |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 39          |
# |    time_elapsed         | 676         |
# |    total_timesteps      | 39000       |
# | train/                  |             |
# |    approx_kl            | 0.021308599 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.01        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00407     |
# |    std                  | 0.993       |
# |    value_loss           | 7.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -22.2       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 40          |
# |    time_elapsed         | 694         |
# |    total_timesteps      | 40000       |
# | train/                  |             |
# |    approx_kl            | 0.026350494 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.53        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.000468    |
# |    std                  | 0.993       |
# |    value_loss           | 7.99        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -20.3       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 41          |
# |    time_elapsed         | 712         |
# |    total_timesteps      | 41000       |
# | train/                  |             |
# |    approx_kl            | 0.025291864 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.33        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00599    |
# |    std                  | 0.993       |
# |    value_loss           | 14.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -11.3       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 42          |
# |    time_elapsed         | 730         |
# |    total_timesteps      | 42000       |
# | train/                  |             |
# |    approx_kl            | 0.012185548 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.38        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 1.69e-05    |
# |    std                  | 0.993       |
# |    value_loss           | 7.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -3.06       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 43          |
# |    time_elapsed         | 747         |
# |    total_timesteps      | 43000       |
# | train/                  |             |
# |    approx_kl            | 0.012465273 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.51        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00212    |
# |    std                  | 0.993       |
# |    value_loss           | 16.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 0.978       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 44          |
# |    time_elapsed         | 765         |
# |    total_timesteps      | 44000       |
# | train/                  |             |
# |    approx_kl            | 0.007919591 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.66        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00457    |
# |    std                  | 0.993       |
# |    value_loss           | 21.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 0.995       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 45          |
# |    time_elapsed         | 783         |
# |    total_timesteps      | 45000       |
# | train/                  |             |
# |    approx_kl            | 0.023072796 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.61        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.0157      |
# |    std                  | 0.993       |
# |    value_loss           | 13.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 0.202       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 46          |
# |    time_elapsed         | 801         |
# |    total_timesteps      | 46000       |
# | train/                  |             |
# |    approx_kl            | 0.010336931 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.12        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00061     |
# |    std                  | 0.993       |
# |    value_loss           | 8.06        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 3.71        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 47          |
# |    time_elapsed         | 819         |
# |    total_timesteps      | 47000       |
# | train/                  |             |
# |    approx_kl            | 0.011088518 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.24        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00394    |
# |    std                  | 0.992       |
# |    value_loss           | 5.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 7.9         |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 48          |
# |    time_elapsed         | 836         |
# |    total_timesteps      | 48000       |
# | train/                  |             |
# |    approx_kl            | 0.012538815 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.51        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.000471   |
# |    std                  | 0.992       |
# |    value_loss           | 9.86        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 11.5        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 49          |
# |    time_elapsed         | 854         |
# |    total_timesteps      | 49000       |
# | train/                  |             |
# |    approx_kl            | 0.007858768 |
# |    clip_fraction        | 0.0819      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.98        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00179    |
# |    std                  | 0.992       |
# |    value_loss           | 16.7        |
# -----------------------------------------
# /Users/PrishitaRay1/opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=50000, episode_reward=-20.93 +/- 47.46
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | -20.9        |
# | time/                   |              |
# |    total_timesteps      | 50000        |
# | train/                  |              |
# |    approx_kl            | 0.0114768725 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.37         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00118     |
# |    std                  | 0.992        |
# |    value_loss           | 7.69         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 20       |
# | time/              |          |
# |    fps             | 55       |
# |    iterations      | 50       |
# |    time_elapsed    | 908      |
# |    total_timesteps | 50000    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 25.8         |
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 51           |
# |    time_elapsed         | 925          |
# |    total_timesteps      | 51000        |
# | train/                  |              |
# |    approx_kl            | 0.0055713416 |
# |    clip_fraction        | 0.235        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | 0.788        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 11.1         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0021      |
# |    std                  | 0.992        |
# ...
# |    n_updates            | 9820       |
# |    policy_gradient_loss | 0.0184     |
# |    std                  | 0.989      |
# |    value_loss           | 53.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | 691         |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 984         |
# |    time_elapsed         | 17041       |
# |    total_timesteps      | 984000      |
# | train/                  |             |
# |    approx_kl            | 0.060622197 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 36.7        |
# |    n_updates            | 9830        |
# |    policy_gradient_loss | 0.0127      |
# |    std                  | 0.989       |
# |    value_loss           | 111         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 985        |
# |    ep_rew_mean          | 691        |
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 985        |
# |    time_elapsed         | 17058      |
# |    total_timesteps      | 985000     |
# | train/                  |            |
# |    approx_kl            | 0.26119095 |
# |    clip_fraction        | 0.456      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.21      |
# |    explained_variance   | 0.827      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 38         |
# |    n_updates            | 9840       |
# |    policy_gradient_loss | 0.0427     |
# |    std                  | 0.989      |
# |    value_loss           | 84.9       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 985        |
# |    ep_rew_mean          | 691        |
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 986        |
# |    time_elapsed         | 17074      |
# |    total_timesteps      | 986000     |
# | train/                  |            |
# |    approx_kl            | 0.07642076 |
# |    clip_fraction        | 0.459      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.21      |
# |    explained_variance   | 0.82       |
# |    learning_rate        | 0.00025    |
# |    loss                 | 31         |
# |    n_updates            | 9850       |
# |    policy_gradient_loss | 0.0583     |
# |    std                  | 0.989      |
# |    value_loss           | 61.8       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 985        |
# |    ep_rew_mean          | 691        |
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 987        |
# |    time_elapsed         | 17090      |
# |    total_timesteps      | 987000     |
# | train/                  |            |
# |    approx_kl            | 0.03217622 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.21      |
# |    explained_variance   | 0.828      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 39.2       |
# |    n_updates            | 9860       |
# |    policy_gradient_loss | 0.0146     |
# |    std                  | 0.99       |
# |    value_loss           | 69.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | 693         |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 988         |
# |    time_elapsed         | 17107       |
# |    total_timesteps      | 988000      |
# | train/                  |             |
# |    approx_kl            | 0.034122836 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 18.9        |
# |    n_updates            | 9870        |
# |    policy_gradient_loss | 0.00897     |
# |    std                  | 0.99        |
# |    value_loss           | 56.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | 693         |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 989         |
# |    time_elapsed         | 17124       |
# |    total_timesteps      | 989000      |
# | train/                  |             |
# |    approx_kl            | 0.010975421 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.1        |
# |    n_updates            | 9880        |
# |    policy_gradient_loss | 0.000431    |
# |    std                  | 0.99        |
# |    value_loss           | 49.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 985        |
# |    ep_rew_mean          | 692        |
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 990        |
# |    time_elapsed         | 17140      |
# |    total_timesteps      | 990000     |
# | train/                  |            |
# |    approx_kl            | 0.07516659 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.21      |
# |    explained_variance   | 0.801      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 39.3       |
# |    n_updates            | 9890       |
# |    policy_gradient_loss | 0.0123     |
# |    std                  | 0.99       |
# |    value_loss           | 83.7       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 985        |
# |    ep_rew_mean          | 691        |
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 991        |
# |    time_elapsed         | 17157      |
# |    total_timesteps      | 991000     |
# | train/                  |            |
# |    approx_kl            | 0.12211408 |
# |    clip_fraction        | 0.428      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.22      |
# |    explained_variance   | 0.893      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 23.7       |
# |    n_updates            | 9900       |
# |    policy_gradient_loss | 0.0355     |
# |    std                  | 0.99       |
# |    value_loss           | 62         |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 985        |
# |    ep_rew_mean          | 690        |
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 992        |
# |    time_elapsed         | 17173      |
# |    total_timesteps      | 992000     |
# | train/                  |            |
# |    approx_kl            | 0.05581538 |
# |    clip_fraction        | 0.365      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.22      |
# |    explained_variance   | 0.827      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 26         |
# |    n_updates            | 9910       |
# |    policy_gradient_loss | 0.0165     |
# |    std                  | 0.99       |
# |    value_loss           | 42.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 985        |
# |    ep_rew_mean          | 691        |
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 993        |
# |    time_elapsed         | 17190      |
# |    total_timesteps      | 993000     |
# | train/                  |            |
# |    approx_kl            | 0.10073107 |
# |    clip_fraction        | 0.634      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.22      |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 14.1       |
# |    n_updates            | 9920       |
# |    policy_gradient_loss | 0.086      |
# |    std                  | 0.99       |
# |    value_loss           | 34.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | 689         |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 994         |
# |    time_elapsed         | 17206       |
# |    total_timesteps      | 994000      |
# | train/                  |             |
# |    approx_kl            | 0.116903946 |
# |    clip_fraction        | 0.624       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15          |
# |    n_updates            | 9930        |
# |    policy_gradient_loss | 0.109       |
# |    std                  | 0.991       |
# |    value_loss           | 58.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 985        |
# |    ep_rew_mean          | 687        |
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 995        |
# |    time_elapsed         | 17223      |
# |    total_timesteps      | 995000     |
# | train/                  |            |
# |    approx_kl            | 0.40256494 |
# |    clip_fraction        | 0.637      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.22      |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 25.9       |
# |    n_updates            | 9940       |
# |    policy_gradient_loss | 0.099      |
# |    std                  | 0.991      |
# |    value_loss           | 55         |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 985       |
# |    ep_rew_mean          | 686       |
# | time/                   |           |
# |    fps                  | 57        |
# |    iterations           | 996       |
# |    time_elapsed         | 17240     |
# |    total_timesteps      | 996000    |
# | train/                  |           |
# |    approx_kl            | 0.0431478 |
# |    clip_fraction        | 0.219     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.22     |
# |    explained_variance   | 0.917     |
# |    learning_rate        | 0.00025   |
# |    loss                 | 19.8      |
# |    n_updates            | 9950      |
# |    policy_gradient_loss | 0.00489   |
# |    std                  | 0.991     |
# |    value_loss           | 49        |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | 687         |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 997         |
# |    time_elapsed         | 17256       |
# |    total_timesteps      | 997000      |
# | train/                  |             |
# |    approx_kl            | 0.046613786 |
# |    clip_fraction        | 0.351       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 23.1        |
# |    n_updates            | 9960        |
# |    policy_gradient_loss | 0.0313      |
# |    std                  | 0.991       |
# |    value_loss           | 73.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 985        |
# |    ep_rew_mean          | 688        |
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 998        |
# |    time_elapsed         | 17273      |
# |    total_timesteps      | 998000     |
# | train/                  |            |
# |    approx_kl            | 0.07972621 |
# |    clip_fraction        | 0.272      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.22      |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 35.3       |
# |    n_updates            | 9970       |
# |    policy_gradient_loss | 0.0158     |
# |    std                  | 0.991      |
# |    value_loss           | 78.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | 687         |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 999         |
# |    time_elapsed         | 17289       |
# |    total_timesteps      | 999000      |
# | train/                  |             |
# |    approx_kl            | 0.021003542 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 43.3        |
# |    n_updates            | 9980        |
# |    policy_gradient_loss | 0.00763     |
# |    std                  | 0.991       |
# |    value_loss           | 81.7        |
# -----------------------------------------
# Eval num_timesteps=1000000, episode_reward=706.05 +/- 204.28
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 706         |
# | time/                   |             |
# |    total_timesteps      | 1000000     |
# | train/                  |             |
# |    approx_kl            | 0.013944658 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.1        |
# |    n_updates            | 9990        |
# |    policy_gradient_loss | 0.00259     |
# |    std                  | 0.991       |
# |    value_loss           | 46          |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 985      |
# |    ep_rew_mean     | 688      |
# | time/              |          |
# |    fps             | 57       |
# |    iterations      | 1000     |
# |    time_elapsed    | 17342    |
# |    total_timesteps | 1000000  |
# ---------------------------------

# %% [markdown]
# **4.Evaluating Models**- Best Model

# %%
ppo_path = os.path.join('./Training/Saved_Models/PPO_car_best_Model_curriculum/best_model.zip')

# %%
best_model = PPO.load(ppo_path, env=eval_env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
evalue = evaluate_policy(best_model, eval_env, n_eval_episodes=500, render = False)
eval_env.close()
evalue
# Out:
# /Users/PrishitaRay1/opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 evalue = evaluate_policy(best_model, eval_env, n_eval_episodes=500, render = False)
#       2 eval_env.close()
#       3 evalue
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:89, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      87 while (episode_counts < episode_count_targets).any():
#      88     actions, states = model.predict(observations, state=states, episode_start=episode_starts, deterministic=deterministic)
# ---> 89     observations, rewards, dones, infos = env.step(actions)
#      90     current_rewards += rewards
#      91     current_lengths += 1
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:163, in VecEnv.step(self, actions)
#     156 """
#     157 Step the environments with the given action
#     158
#     159 :param actions: the action
#     160 :return: observation, reward, done, information
#     161 """
#     162 self.step_async(actions)
# --> 163 return self.step_wait()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:62, in DummyVecEnv.step_wait(self)
#      60         obs = self.envs[env_idx].reset()
#      61     self._save_obs(env_idx, obs)
# ---> 62 return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# File ~/opt/anaconda3/lib/python3.9/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/opt/anaconda3/lib/python3.9/copy.py:205, in _deepcopy_list(x, memo, deepcopy)
#     203 append = y.append
#     204 for a in x:
# --> 205     append(deepcopy(a, memo))
#     206 return y
#
# File ~/opt/anaconda3/lib/python3.9/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/opt/anaconda3/lib/python3.9/copy.py:228, in _deepcopy_dict(x, memo, deepcopy)
#     226 def _deepcopy_dict(x, memo, deepcopy=deepcopy):
#     227     y = {}
# --> 228     memo[id(x)] = y
#     229     for key, value in x.items():
#     230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#
# KeyboardInterrupt:

# %%
# To calculate number of tiles covered and time taken in default environment

episodes = 500
frames = []

tiles=0
times=0

for episode in range(1, episodes+1):
    obs = eval_env.reset()  #state = env.reset()
    done = False
    score = 0
    
    info={}
    
    while not done:
        # frames.append(env.render(mode='rgb_array'))
        action , _ = best_model.predict(obs.copy()) 
        obs, reward, done, info = eval_env.step(action) 
        score += reward
    
    tiles+=eval_env.tile_visited_count
    times+=eval_env.t
    
    print("Episode:{} Score:{}".format(episode,score))
    
print("Number of tiles:",tiles/500)
print("Time taken:",times/500)
eval_env.close()
# Out:
# Track generation: 1128..1422 -> 294-tiles track
# Total number of obstacles in the track: 9
# Episode:1 Score:331.22866894198035
# Track generation: 1087..1369 -> 282-tiles track
# Total number of obstacles in the track: 8
# Episode:2 Score:49.46619217082231
# Track generation: 972..1215 -> 243-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1160..1454 -> 294-tiles track
# Total number of obstacles in the track: 8
# Episode:3 Score:654.436860068249
# Track generation: 1262..1581 -> 319-tiles track
# Total number of obstacles in the track: 9
# Episode:4 Score:513.8364779874099
# Track generation: 1199..1503 -> 304-tiles track
# Total number of obstacles in the track: 7
# Episode:5 Score:301.65016501649194
# Track generation: 1091..1368 -> 277-tiles track
# Total number of obstacles in the track: 8
# Episode:6 Score:137.49420289854834
# Track generation: 1182..1481 -> 299-tiles track
# Total number of obstacles in the track: 8
# Episode:7 Score:505.0335570469758
# Track generation: 1152..1444 -> 292-tiles track
# Total number of obstacles in the track: 7
# Episode:8 Score:617.8694158075507
# Track generation: 957..1205 -> 248-tiles track
# Total number of obstacles in the track: 8
# Episode:9 Score:778.5425101214432
# Track generation: 1169..1465 -> 296-tiles track
# Total number of obstacles in the track: 10
# Episode:10 Score:656.7796610169381
# Track generation: 969..1221 -> 252-tiles track
# Total number of obstacles in the track: 6
# Episode:11 Score:810.1593625497896
# Track generation: 1303..1633 -> 330-tiles track
# Total number of obstacles in the track: 9
# Episode:12 Score:588.6018237081964
# Track generation: 1067..1338 -> 271-tiles track
# Total number of obstacles in the track: 7
# Episode:13 Score:757.4074074073936
# Track generation: 1068..1339 -> 271-tiles track
# Total number of obstacles in the track: 9
# Episode:14 Score:370.3111111110991
# Track generation: 1207..1513 -> 306-tiles track
# Total number of obstacles in the track: 7
# Episode:15 Score:448.3606557376927
# Track generation: 1078..1359 -> 281-tiles track
# Total number of obstacles in the track: 8
# Episode:16 Score:31.257142857144117
# Track generation: 1258..1580 -> 322-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1030..1297 -> 267-tiles track
# Total number of obstacles in the track: 7
# Episode:17 Score:50.37593984962805
# Track generation: 1219..1528 -> 309-tiles track
# Total number of obstacles in the track: 10
# Episode:18 Score:322.07792207792414
# Track generation: 1205..1509 -> 304-tiles track
# Total number of obstacles in the track: 10
# Episode:19 Score:551.9801980197942
# Track generation: 1206..1512 -> 306-tiles track
# Total number of obstacles in the track: 7
# Episode:20 Score:505.73770491802446
# Track generation: 1200..1504 -> 304-tiles track
# Total number of obstacles in the track: 7
# Episode:21 Score:568.976897689763
# Track generation: 1077..1357 -> 280-tiles track
# Total number of obstacles in the track: 6
# Episode:22 Score:706.6308243727461
# Track generation: 1322..1664 -> 342-tiles track
# Total number of obstacles in the track: 10
# Episode:23 Score:547.9472140762366
# Track generation: 1016..1274 -> 258-tiles track
# Total number of obstacles in the track: 8
# Episode:24 Score:410.31128404668016
# Track generation: 1288..1614 -> 326-tiles track
# Total number of obstacles in the track: 11
# Episode:25 Score:545.3846153846065
# Track generation: 1294..1621 -> 327-tiles track
# Total number of obstacles in the track: 8
# Episode:26 Score:616.871165644163
# Track generation: 1041..1312 -> 271-tiles track
# Total number of obstacles in the track: 8
# Episode:27 Score:437.0370370370253
# Track generation: 1194..1497 -> 303-tiles track
# Total number of obstacles in the track: 7
# Episode:28 Score:674.8344370860831
# Track generation: 886..1109 -> 223-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1212..1519 -> 307-tiles track
# Total number of obstacles in the track: 9
# Episode:29 Score:447.0588235294021
# Track generation: 1317..1652 -> 335-tiles track
# Total number of obstacles in the track: 6
# Episode:30 Score:465.86826347304276
# Track generation: 1103..1386 -> 283-tiles track
# Total number of obstacles in the track: 10
# Episode:31 Score:339.3617021276603
# Track generation: 1148..1439 -> 291-tiles track
# Total number of obstacles in the track: 8
# Episode:32 Score:710.3448275861917
# Track generation: 1043..1308 -> 265-tiles track
# Total number of obstacles in the track: 7
# Episode:33 Score:850.7575757575605
# Track generation: 1192..1494 -> 302-tiles track
# Total number of obstacles in the track: 6
# Episode:34 Score:564.1196013288945
# Track generation: 1223..1532 -> 309-tiles track
# Total number of obstacles in the track: 9
# Episode:35 Score:348.0519480519369
# Track generation: 1094..1372 -> 278-tiles track
# Total number of obstacles in the track: 8
# Episode:36 Score:677.2563176895236
# Track generation: 1179..1478 -> 299-tiles track
# Total number of obstacles in the track: 10
# Episode:37 Score:652.3489932885768
# Track generation: 1028..1289 -> 261-tiles track
# Total number of obstacles in the track: 9
# Episode:38 Score:796.1538461538292
# Track generation: 1061..1332 -> 271-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1104..1384 -> 280-tiles track
# Total number of obstacles in the track: 6
# Episode:39 Score:301.43369175625946
# Track generation: 1295..1623 -> 328-tiles track
# Total number of obstacles in the track: 11
# Episode:40 Score:501.3761467889845
# Track generation: 1255..1573 -> 318-tiles track
# Total number of obstacles in the track: 12
# Episode:41 Score:380.4416403785442
# Track generation: 1052..1319 -> 267-tiles track
# Total number of obstacles in the track: 9
# Episode:42 Score:671.0526315789338
# Track generation: 1084..1367 -> 283-tiles track
# Total number of obstacles in the track: 7
# Episode:43 Score:736.8794326241042
# Track generation: 1121..1406 -> 285-tiles track
# Total number of obstacles in the track: 6
# Episode:44 Score:364.78873239435393
# Track generation: 1099..1378 -> 279-tiles track
# Total number of obstacles in the track: 10
# Episode:45 Score:802.877697841711
# Track generation: 1154..1449 -> 295-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1180..1479 -> 299-tiles track
# Total number of obstacles in the track: 6
# Episode:46 Score:567.7852348993188
# Track generation: 1155..1448 -> 293-tiles track
# Total number of obstacles in the track: 7
# Episode:47 Score:578.7671232876614
# Track generation: 1304..1634 -> 330-tiles track
# Total number of obstacles in the track: 9
# Episode:48 Score:430.54711246200316
# Track generation: 1180..1479 -> 299-tiles track
# Total number of obstacles in the track: 10
# Episode:49 Score:662.0805369127393
# Track generation: 1152..1444 -> 292-tiles track
# Total number of obstacles in the track: 10
# Episode:50 Score:652.233676975931
# Track generation: 1019..1278 -> 259-tiles track
# Total number of obstacles in the track: 8
# Episode:51 Score:741.472868217045
# Track generation: 1216..1524 -> 308-tiles track
# Total number of obstacles in the track: 7
# Episode:52 Score:674.1042345276721
# Track generation: 1003..1259 -> 256-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1264..1584 -> 320-tiles track
# Total number of obstacles in the track: 11
# Episode:53 Score:292.00626959246557
# Track generation: 1232..1544 -> 312-tiles track
# Total number of obstacles in the track: 11
# Episode:54 Score:173.41318327973352
# Track generation: 1174..1471 -> 297-tiles track
# Total number of obstacles in the track: 10
# Episode:55 Score:408.1081081080976
# Track generation: 1243..1564 -> 321-tiles track
# Total number of obstacles in the track: 6
# Episode:56 Score:28.12500000000218
# Track generation: 1033..1296 -> 263-tiles track
# Total number of obstacles in the track: 9
# Episode:57 Score:525.1908396946513
# Track generation: 1345..1685 -> 340-tiles track
# Total number of obstacles in the track: 9
# Episode:58 Score:375.51622418878674
# Track generation: 920..1157 -> 237-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1041..1305 -> 264-tiles track
# Total number of obstacles in the track: 7
# Episode:59 Score:618.6311787072092
# Track generation: 969..1220 -> 251-tiles track
# Total number of obstacles in the track: 6
# Episode:60 Score:815.999999999986
# Track generation: 1220..1529 -> 309-tiles track
# Total number of obstacles in the track: 8
# Episode:61 Score:205.19480519480746
# Track generation: 1062..1332 -> 270-tiles track
# Total number of obstacles in the track: 6
# Episode:62 Score:121.37546468401919
# Track generation: 1143..1433 -> 290-tiles track
# Total number of obstacles in the track: 9
# Episode:63 Score:638.9273356401314
# Track generation: 1063..1333 -> 270-tiles track
# Total number of obstacles in the track: 8
# Episode:64 Score:764.4981412639281
# Track generation: 1106..1387 -> 281-tiles track
# Total number of obstacles in the track: 9
# Episode:65 Score:657.1428571428429
# Track generation: 1067..1338 -> 271-tiles track
# Total number of obstacles in the track: 9
# Episode:66 Score:668.5185185185062
# Track generation: 1285..1611 -> 326-tiles track
# Total number of obstacles in the track: 10
# Episode:67 Score:391.5384615384541
# Track generation: 1198..1502 -> 304-tiles track
# Total number of obstacles in the track: 10
# Episode:68 Score:210.23102310231445
# Track generation: 1095..1373 -> 278-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1209..1515 -> 306-tiles track
# Total number of obstacles in the track: 8
# Episode:69 Score:669.6721311475302
# Track generation: 1167..1463 -> 296-tiles track
# Total number of obstacles in the track: 5
# Episode:70 Score:689.8305084745634
# Track generation: 1199..1503 -> 304-tiles track
# Total number of obstacles in the track: 10
# Episode:71 Score:434.158415841574
# Track generation: 1292..1619 -> 327-tiles track
# Total number of obstacles in the track: 10
# Episode:72 Score:697.5460122699294
# Track generation: 1099..1378 -> 279-tiles track
# Total number of obstacles in the track: 9
# Episode:73 Score:591.726618705024
# Track generation: 1179..1478 -> 299-tiles track
# Total number of obstacles in the track: 5
# Episode:74 Score:698.9932885905909
# Track generation: 1096..1374 -> 278-tiles track
# Total number of obstacles in the track: 5
# Episode:75 Score:738.0866425992714
# Track generation: 1194..1500 -> 306-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1256..1574 -> 318-tiles track
# Total number of obstacles in the track: 8
# Episode:76 Score:319.08643533121887
# Track generation: 1234..1555 -> 321-tiles track
# Total number of obstacles in the track: 10
# Episode:77 Score:481.24999999998954
# Track generation: 1211..1525 -> 314-tiles track
# Total number of obstacles in the track: 8
# Episode:78 Score:219.48881789137883
# Track generation: 1214..1522 -> 308-tiles track
# Total number of obstacles in the track: 11
# Episode:79 Score:527.5244299674183
# Track generation: 1129..1421 -> 292-tiles track
# Total number of obstacles in the track: 11
# Episode:80 Score:542.6116838487859
# Track generation: 1213..1529 -> 316-tiles track
# Total number of obstacles in the track: 8
# Episode:81 Score:459.5238095238053
# Track generation: 1252..1569 -> 317-tiles track
# Total number of obstacles in the track: 9
# Episode:82 Score:377.848101265821
# Track generation: 1040..1304 -> 264-tiles track
# Total number of obstacles in the track: 6
# Episode:83 Score:704.9429657794515
# Track generation: 1118..1401 -> 283-tiles track
# Total number of obstacles in the track: 9
# Episode:84 Score:498.581560283683
# Track generation: 1118..1405 -> 287-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1042..1309 -> 267-tiles track
# Total number of obstacles in the track: 7
# Episode:85 Score:831.2030075187814
# Track generation: 1208..1514 -> 306-tiles track
# Total number of obstacles in the track: 10
# Episode:86 Score:726.2295081967096
# Track generation: 1140..1429 -> 289-tiles track
# Total number of obstacles in the track: 9
# Episode:87 Score:621.527777777764
# Track generation: 1114..1400 -> 286-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1052..1319 -> 267-tiles track
# Total number of obstacles in the track: 7
# Episode:88 Score:738.3458646616385
# Track generation: 1042..1309 -> 267-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1122..1407 -> 285-tiles track
# Total number of obstacles in the track: 9
# Episode:89 Score:549.2957746478769
# Track generation: 1193..1502 -> 309-tiles track
# Total number of obstacles in the track: 11
# Episode:90 Score:453.2467532467477
# Track generation: 1217..1525 -> 308-tiles track
# Total number of obstacles in the track: 10
# Episode:91 Score:645.9283387622031
# Track generation: 1014..1273 -> 259-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1120..1404 -> 284-tiles track
# Total number of obstacles in the track: 7
# Episode:92 Score:527.9151943462853
# Track generation: 1144..1443 -> 299-tiles track
# Total number of obstacles in the track: 9
# Episode:93 Score:518.1208053691214
# Track generation: 1300..1629 -> 329-tiles track
# Total number of obstacles in the track: 10
# Episode:94 Score:271.9512195122
# Track generation: 992..1244 -> 252-tiles track
# Total number of obstacles in the track: 4
# Episode:95 Score:806.1752988047698
# Track generation: 1239..1553 -> 314-tiles track
# Total number of obstacles in the track: 11
# Episode:96 Score:650.798722044719
# Track generation: 1306..1642 -> 336-tiles track
# Total number of obstacles in the track: 7
# Episode:97 Score:192.53731343283917
# Track generation: 1208..1515 -> 307-tiles track
# Total number of obstacles in the track: 8
# Episode:98 Score:461.11111111109983
# Track generation: 975..1223 -> 248-tiles track
# Total number of obstacles in the track: 8
# Episode:99 Score:763.5627530364212
# Track generation: 1068..1339 -> 271-tiles track
# Total number of obstacles in the track: 6
# Episode:100 Score:859.2592592592435
# Track generation: 1141..1430 -> 289-tiles track
# Total number of obstacles in the track: 9
# Episode:101 Score:374.30555555554616
# Track generation: 1157..1450 -> 293-tiles track
# Total number of obstacles in the track: 10
# Episode:102 Score:519.1780821917713
# Track generation: 1070..1341 -> 271-tiles track
# Total number of obstacles in the track: 7
# Episode:103 Score:418.5185185185053
# Track generation: 1231..1543 -> 312-tiles track
# Total number of obstacles in the track: 8
# Episode:104 Score:227.97427652732725
# Track generation: 1168..1464 -> 296-tiles track
# Total number of obstacles in the track: 10
# Episode:105 Score:518.6440677966016
# Track generation: 1017..1276 -> 259-tiles track
# Total number of obstacles in the track: 6
# Episode:106 Score:404.2635658914635
# Track generation: 1190..1491 -> 301-tiles track
# Total number of obstacles in the track: 9
# Episode:107 Score:529.9999999999899
# Track generation: 1283..1608 -> 325-tiles track
# Total number of obstacles in the track: 10
# Episode:108 Score:523.4567901234481
# Track generation: 1172..1469 -> 297-tiles track
# Total number of obstacles in the track: 9
# Episode:109 Score:681.081081081067
# Track generation: 1055..1323 -> 268-tiles track
# Total number of obstacles in the track: 9
# Episode:110 Score:686.3295880149715
# Track generation: 1120..1404 -> 284-tiles track
# Total number of obstacles in the track: 8
# Episode:111 Score:517.8445229681881
# Track generation: 1203..1507 -> 304-tiles track
# Total number of obstacles in the track: 9
# Episode:112 Score:122.93564356435925
# Track generation: 1151..1443 -> 292-tiles track
# Total number of obstacles in the track: 5
# Episode:113 Score:654.1237113401922
# Track generation: 1167..1463 -> 296-tiles track
# Total number of obstacles in the track: 7
# Episode:114 Score:774.5762711864274
# Track generation: 1196..1499 -> 303-tiles track
# Total number of obstacles in the track: 8
# Episode:115 Score:395.03311258277927
# Track generation: 1273..1595 -> 322-tiles track
# Total number of obstacles in the track: 9
# Episode:116 Score:335.8255451713398
# Track generation: 1244..1559 -> 315-tiles track
# Total number of obstacles in the track: 9
# Episode:117 Score:406.36942675158184
# Track generation: 1143..1433 -> 290-tiles track
# Total number of obstacles in the track: 11
# Episode:118 Score:457.4394463667724
# Track generation: 1119..1403 -> 284-tiles track
# Total number of obstacles in the track: 9
# Episode:119 Score:570.8480565370911
# Track generation: 1143..1433 -> 290-tiles track
# Total number of obstacles in the track: 10
# Episode:120 Score:480.44982698961263
# Track generation: 1171..1468 -> 297-tiles track
# Total number of obstacles in the track: 9
# Episode:121 Score:472.9729729729625
# Track generation: 1128..1414 -> 286-tiles track
# Total number of obstacles in the track: 4
# Episode:122 Score:702.6315789473532
# Track generation: 1173..1470 -> 297-tiles track
# Total number of obstacles in the track: 7
# Episode:123 Score:377.1459459459356
# Track generation: 1119..1403 -> 284-tiles track
# Total number of obstacles in the track: 11
# Episode:124 Score:567.3144876324985
# Track generation: 1148..1439 -> 291-tiles track
# Total number of obstacles in the track: 11
# Episode:125 Score:544.827586206885
# Track generation: 1159..1453 -> 294-tiles track
# Total number of obstacles in the track: 8
# Episode:126 Score:399.48805460749526
# Track generation: 1207..1513 -> 306-tiles track
# Total number of obstacles in the track: 8
# Episode:127 Score:755.7377049180205
# Track generation: 1100..1379 -> 279-tiles track
# Total number of obstacles in the track: 8
# Episode:128 Score:556.1151079136588
# Track generation: 1091..1376 -> 285-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1297..1626 -> 329-tiles track
# Total number of obstacles in the track: 5
# Episode:129 Score:478.04878048779665
# Track generation: 1009..1265 -> 256-tiles track
# Total number of obstacles in the track: 8
# Episode:130 Score:787.2549019607671
# Track generation: 1092..1369 -> 277-tiles track
# Total number of obstacles in the track: 6
# Episode:131 Score:773.1884057970909
# Track generation: 1087..1398 -> 311-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1099..1380 -> 281-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1196..1500 -> 304-tiles track
# Total number of obstacles in the track: 7
# Episode:132 Score:472.7722772277133
# Track generation: 1186..1487 -> 301-tiles track
# Total number of obstacles in the track: 9
# Episode:133 Score:313.3333333333223
# Track generation: 1056..1324 -> 268-tiles track
# Total number of obstacles in the track: 5
# Episode:134 Score:353.4617977527963
# Track generation: 955..1204 -> 249-tiles track
# Total number of obstacles in the track: 6
# Episode:135 Score:724.9999999999889
# Track generation: 1224..1534 -> 310-tiles track
# Total number of obstacles in the track: 10
# Episode:136 Score:717.3139158575926
# Track generation: 1139..1428 -> 289-tiles track
# Total number of obstacles in the track: 9
# Episode:137 Score:568.7499999999877
# Track generation: 1143..1433 -> 290-tiles track
# Total number of obstacles in the track: 4
# Episode:138 Score:830.795847750856
# Track generation: 1256..1573 -> 317-tiles track
# Total number of obstacles in the track: 9
# Episode:139 Score:374.6835443037855
# Track generation: 1049..1315 -> 266-tiles track
# Total number of obstacles in the track: 7
# Episode:140 Score:847.1698113207425
# Track generation: 1272..1594 -> 322-tiles track
# Total number of obstacles in the track: 7
# Episode:141 Score:519.9376947040416
# Track generation: 1095..1373 -> 278-tiles track
# Total number of obstacles in the track: 9
# Episode:142 Score:709.7472924187621
# Track generation: 1057..1325 -> 268-tiles track
# Total number of obstacles in the track: 4
# Episode:143 Score:855.05617977527
# Track generation: 1094..1376 -> 282-tiles track
# Total number of obstacles in the track: 9
# Episode:144 Score:109.9644128113923
# Track generation: 944..1184 -> 240-tiles track
# Total number of obstacles in the track: 7
# Episode:145 Score:620.5020920501943
# Track generation: 1244..1559 -> 315-tiles track
# Total number of obstacles in the track: 12
# Episode:146 Score:459.23566878979534
# Track generation: 1333..1670 -> 337-tiles track
# Total number of obstacles in the track: 7
# Episode:147 Score:403.5714285714181
# Track generation: 1115..1398 -> 283-tiles track
# Total number of obstacles in the track: 8
# Episode:148 Score:665.2482269503466
# Track generation: 1196..1499 -> 303-tiles track
# Total number of obstacles in the track: 9
# Episode:149 Score:479.1390728476721
# Track generation: 1148..1439 -> 291-tiles track
# Total number of obstacles in the track: 7
# Episode:150 Score:686.2068965517097
# Track generation: 1180..1479 -> 299-tiles track
# Total number of obstacles in the track: 11
# Episode:151 Score:682.2147651006596
# Track generation: 1124..1409 -> 285-tiles track
# Total number of obstacles in the track: 9
# Episode:152 Score:465.49295774647703
# Track generation: 1188..1489 -> 301-tiles track
# Total number of obstacles in the track: 9
# Episode:153 Score:343.3333333333285
# Track generation: 1157..1450 -> 293-tiles track
# Total number of obstacles in the track: 9
# Episode:154 Score:660.273972602727
# Track generation: 1148..1439 -> 291-tiles track
# Total number of obstacles in the track: 9
# Episode:155 Score:598.2758620689542
# Track generation: 947..1196 -> 249-tiles track
# Total number of obstacles in the track: 7
# Episode:156 Score:105.6451612903274
# Track generation: 1285..1610 -> 325-tiles track
# Total number of obstacles in the track: 8
# Episode:157 Score:343.8271604938268
# Track generation: 1016..1274 -> 258-tiles track
# Total number of obstacles in the track: 9
# Episode:158 Score:559.3385214007686
# Track generation: 1124..1409 -> 285-tiles track
# Total number of obstacles in the track: 6
# Episode:159 Score:765.4929577464626
# Track generation: 1152..1451 -> 299-tiles track
# Total number of obstacles in the track: 7
# Episode:160 Score:326.17449664428403
# Track generation: 1308..1639 -> 331-tiles track
# Total number of obstacles in the track: 9
# Episode:161 Score:212.12121212121352
# Track generation: 1293..1623 -> 330-tiles track
# Total number of obstacles in the track: 9
# Episode:162 Score:544.680851063822
# Track generation: 1070..1342 -> 272-tiles track
# Total number of obstacles in the track: 7
# Episode:163 Score:740.9594095940864
# Track generation: 1143..1433 -> 290-tiles track
# Total number of obstacles in the track: 2
# Episode:164 Score:336.33217993078495
# Track generation: 1146..1446 -> 300-tiles track
# Total number of obstacles in the track: 9
# Episode:165 Score:622.57525083611
# Track generation: 1114..1401 -> 287-tiles track
# Total number of obstacles in the track: 6
# Episode:166 Score:60.06573426573735
# Track generation: 1112..1394 -> 282-tiles track
# Total number of obstacles in the track: 9
# Episode:167 Score:661.3879003558629
# Track generation: 995..1255 -> 260-tiles track
# Total number of obstacles in the track: 9
# Episode:168 Score:479.15057915057173
# Track generation: 1167..1463 -> 296-tiles track
# Total number of obstacles in the track: 7
# Episode:169 Score:551.6949152542255
# Track generation: 1091..1370 -> 279-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1308..1639 -> 331-tiles track
# Total number of obstacles in the track: 6
# Episode:170 Score:409.09090909089485
# Track generation: 1136..1424 -> 288-tiles track
# Total number of obstacles in the track: 9
# Episode:171 Score:548.0836236933668
# Track generation: 1139..1428 -> 289-tiles track
# Total number of obstacles in the track: 7
# Episode:172 Score:662.4999999999877
# Track generation: 1144..1434 -> 290-tiles track
# Total number of obstacles in the track: 10
# Episode:173 Score:256.4013840830353
# Track generation: 1046..1320 -> 274-tiles track
# Total number of obstacles in the track: 7
# Episode:174 Score:453.29670329670057
# Track generation: 1098..1383 -> 285-tiles track
# Total number of obstacles in the track: 7
# Episode:175 Score:79.70000000000329
# Track generation: 1191..1501 -> 310-tiles track
# Total number of obstacles in the track: 9
# Episode:176 Score:269.2556634304239
# Track generation: 1058..1328 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1245..1558 -> 313-tiles track
# Total number of obstacles in the track: 4
# Episode:177 Score:682.0512820512698
# Track generation: 1099..1378 -> 279-tiles track
# Total number of obstacles in the track: 9
# Episode:178 Score:674.1007194244465
# Track generation: 1135..1423 -> 288-tiles track
# Total number of obstacles in the track: 7
# Episode:179 Score:563.0662020905842
# Track generation: 1247..1563 -> 316-tiles track
# Total number of obstacles in the track: 6
# Episode:180 Score:554.761904761895
# Track generation: 1192..1494 -> 302-tiles track
# Total number of obstacles in the track: 7
# Episode:181 Score:624.0863787375292
# Track generation: 1314..1647 -> 333-tiles track
# Total number of obstacles in the track: 12
# Episode:182 Score:283.7349397590298
# Track generation: 1104..1384 -> 280-tiles track
# Total number of obstacles in the track: 9
# Episode:183 Score:781.720430107514
# Track generation: 1269..1590 -> 321-tiles track
# Total number of obstacles in the track: 9
# Episode:184 Score:521.8749999999905
# Track generation: 1092..1370 -> 278-tiles track
# Total number of obstacles in the track: 11
# Episode:185 Score:583.3935018050457
# Track generation: 1167..1463 -> 296-tiles track
# Total number of obstacles in the track: 7
# Episode:186 Score:704.2372881355816
# Track generation: 1191..1493 -> 302-tiles track
# Total number of obstacles in the track: 6
# Episode:187 Score:613.7873754152703
# Track generation: 1056..1327 -> 271-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1234..1547 -> 313-tiles track
# Total number of obstacles in the track: 8
# Episode:188 Score:642.9487179487105
# Track generation: 1117..1408 -> 291-tiles track
# Total number of obstacles in the track: 9
# Episode:189 Score:696.5517241379171
# Track generation: 1180..1479 -> 299-tiles track
# Total number of obstacles in the track: 7
# Episode:190 Score:491.2751677852308
# Track generation: 946..1187 -> 241-tiles track
# Total number of obstacles in the track: 7
# Episode:191 Score:774.999999999986
# Track generation: 1188..1489 -> 301-tiles track
# Total number of obstacles in the track: 10
# Episode:192 Score:583.3333333333221
# Track generation: 1088..1364 -> 276-tiles track
# Total number of obstacles in the track: 10
# Episode:193 Score:620.9090909090784
# Track generation: 1175..1473 -> 298-tiles track
# Total number of obstacles in the track: 10
# Episode:194 Score:553.1986531986431
# Track generation: 1203..1507 -> 304-tiles track
# Total number of obstacles in the track: 8
# Episode:195 Score:654.7854785478463
# Track generation: 1232..1544 -> 312-tiles track
# Total number of obstacles in the track: 7
# Episode:196 Score:243.72990353697318
# Track generation: 1189..1490 -> 301-tiles track
# Total number of obstacles in the track: 11
# Episode:197 Score:569.9999999999877
# Track generation: 1167..1463 -> 296-tiles track
# Total number of obstacles in the track: 9
# Episode:198 Score:595.7627118643952
# Track generation: 1134..1430 -> 296-tiles track
# Total number of obstacles in the track: 9
# Episode:199 Score:66.10169491525889
# Track generation: 1247..1563 -> 316-tiles track
# Total number of obstacles in the track: 5
# Episode:200 Score:596.0317460317339
# Track generation: 1209..1515 -> 306-tiles track
# Total number of obstacles in the track: 11
# Episode:201 Score:559.836065573759
# Track generation: 1244..1559 -> 315-tiles track
# Total number of obstacles in the track: 9
# Episode:202 Score:482.4840764331068
# Track generation: 1149..1440 -> 291-tiles track
# Total number of obstacles in the track: 8
# Episode:203 Score:556.8965517241273
# Track generation: 1208..1514 -> 306-tiles track
# Total number of obstacles in the track: 9
# Episode:204 Score:499.99999999999113
# Track generation: 1103..1383 -> 280-tiles track
# Total number of obstacles in the track: 7
# Episode:205 Score:445.3405017921013
# Track generation: 1153..1445 -> 292-tiles track
# Total number of obstacles in the track: 9
# Episode:206 Score:735.0515463917388
# Track generation: 1165..1460 -> 295-tiles track
# Total number of obstacles in the track: 7
# Episode:207 Score:619.7278911564533
# Track generation: 1123..1408 -> 285-tiles track
# Total number of obstacles in the track: 8
# Episode:208 Score:663.3802816901297
# Track generation: 1572..1969 -> 397-tiles track
# Total number of obstacles in the track: 12
# Episode:209 Score:75.25252525252901
# Track generation: 1168..1463 -> 295-tiles track
# Total number of obstacles in the track: 7
# Episode:210 Score:590.4761904761805
# Track generation: 1304..1634 -> 330-tiles track
# Total number of obstacles in the track: 9
# Episode:211 Score:672.0364741641245
# Track generation: 1264..1584 -> 320-tiles track
# Total number of obstacles in the track: 7
# Episode:212 Score:505.32915360500976
# Track generation: 1068..1345 -> 277-tiles track
# Total number of obstacles in the track: 7
# Episode:213 Score:48.550724637684716
# Track generation: 1295..1623 -> 328-tiles track
# Total number of obstacles in the track: 11
# Episode:214 Score:479.96941896023475
# Track generation: 1224..1534 -> 310-tiles track
# Total number of obstacles in the track: 10
# Episode:215 Score:649.3527508090513
# Track generation: 1137..1425 -> 288-tiles track
# Total number of obstacles in the track: 7
# Episode:216 Score:174.04181184669469
# Track generation: 1143..1433 -> 290-tiles track
# Total number of obstacles in the track: 9
# Episode:217 Score:443.598615916946
# Track generation: 1054..1324 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1044..1309 -> 265-tiles track
# Total number of obstacles in the track: 5
# Episode:218 Score:759.0909090908942
# Track generation: 1202..1506 -> 304-tiles track
# Total number of obstacles in the track: 9
# Episode:219 Score:559.075907590751
# Track generation: 1119..1403 -> 284-tiles track
# Total number of obstacles in the track: 8
# Episode:220 Score:676.8551236749026
# Track generation: 1139..1428 -> 289-tiles track
# Total number of obstacles in the track: 11
# Episode:221 Score:574.3055555555438
# Track generation: 1039..1303 -> 264-tiles track
# Total number of obstacles in the track: 7
# Episode:222 Score:616.3498098859206
# Track generation: 1184..1484 -> 300-tiles track
# Total number of obstacles in the track: 8
# Episode:223 Score:692.6421404682136
# Track generation: 1359..1703 -> 344-tiles track
# Total number of obstacles in the track: 10
# Episode:224 Score:235.27696793002548
# Track generation: 1269..1590 -> 321-tiles track
# Total number of obstacles in the track: 11
# Episode:225 Score:159.3750000000037
# Track generation: 1119..1403 -> 284-tiles track
# Total number of obstacles in the track: 6
# Episode:226 Score:387.10247349822293
# Track generation: 1267..1588 -> 321-tiles track
# Total number of obstacles in the track: 8
# Episode:227 Score:106.25000000000435
# Track generation: 1175..1473 -> 298-tiles track
# Total number of obstacles in the track: 7
# Episode:228 Score:621.5488215488108
# Track generation: 1003..1265 -> 262-tiles track
# Total number of obstacles in the track: 6
# Episode:229 Score:746.55172413792
# Track generation: 1029..1292 -> 263-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1339..1678 -> 339-tiles track
# Total number of obstacles in the track: 10
# Episode:230 Score:524.5562130177425
# Track generation: 1143..1433 -> 290-tiles track
# Total number of obstacles in the track: 10
# Episode:231 Score:675.4325259515491
# Track generation: 1183..1483 -> 300-tiles track
# Total number of obstacles in the track: 6
# Episode:232 Score:689.4648829431292
# Track generation: 1102..1378 -> 276-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1200..1504 -> 304-tiles track
# Total number of obstacles in the track: 8
# Episode:233 Score:684.9834983498264
# Track generation: 1095..1376 -> 281-tiles track
# Total number of obstacles in the track: 8
# Episode:234 Score:628.5714285714155
# Track generation: 1147..1438 -> 291-tiles track
# Total number of obstacles in the track: 9
# Episode:235 Score:705.1724137930885
# Track generation: 1227..1538 -> 311-tiles track
# Total number of obstacles in the track: 11
# Episode:236 Score:645.1612903225738
# Track generation: 1030..1296 -> 266-tiles track
# Total number of obstacles in the track: 9
# Episode:237 Score:9.433962264151962
# Track generation: 1330..1667 -> 337-tiles track
# Total number of obstacles in the track: 7
# Episode:238 Score:408.9285714285613
# Track generation: 1080..1355 -> 275-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1195..1498 -> 303-tiles track
# Total number of obstacles in the track: 8
# Episode:239 Score:588.7417218542955
# Track generation: 1099..1378 -> 279-tiles track
# Total number of obstacles in the track: 9
# Episode:240 Score:688.1294964028616
# Track generation: 1147..1438 -> 291-tiles track
# Total number of obstacles in the track: 10
# Episode:241 Score:444.82758620688196
# Track generation: 1167..1466 -> 299-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1106..1389 -> 283-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1164..1459 -> 295-tiles track
# Total number of obstacles in the track: 9
# Episode:242 Score:707.142857142848
# Track generation: 1107..1389 -> 282-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1178..1477 -> 299-tiles track
# Total number of obstacles in the track: 9
# Episode:243 Score:547.9865771811998
# Track generation: 1112..1394 -> 282-tiles track
# Total number of obstacles in the track: 5
# Episode:244 Score:768.1494661921594
# Track generation: 1128..1412 -> 284-tiles track
# Total number of obstacles in the track: 7
# Episode:245 Score:718.7279151943314
# Track generation: 1156..1449 -> 293-tiles track
# Total number of obstacles in the track: 11
# Episode:246 Score:518.4931506849239
# Track generation: 1090..1367 -> 277-tiles track
# Total number of obstacles in the track: 6
# Episode:247 Score:421.73913043476995
# Track generation: 1148..1439 -> 291-tiles track
# Total number of obstacles in the track: 7
# Episode:248 Score:686.2068965517093
# Track generation: 1078..1342 -> 264-tiles track
# Total number of obstacles in the track: 10
# Episode:249 Score:582.6996197718503
# Track generation: 992..1244 -> 252-tiles track
# Total number of obstacles in the track: 8
# Episode:250 Score:806.1752988047701
# Track generation: 1138..1427 -> 289-tiles track
# Total number of obstacles in the track: 8
# Episode:251 Score:761.111111111095
# Track generation: 1312..1644 -> 332-tiles track
# Total number of obstacles in the track: 8
# Episode:252 Score:662.6888217522516
# Track generation: 1129..1415 -> 286-tiles track
# Total number of obstacles in the track: 6
# Episode:253 Score:380.70175438595084
# Track generation: 1011..1268 -> 257-tiles track
# Total number of obstacles in the track: 3
# Episode:254 Score:703.124999999986
# Track generation: 1037..1305 -> 268-tiles track
# Total number of obstacles in the track: 5
# Episode:255 Score:-40.6591760299599
# Track generation: 1081..1355 -> 274-tiles track
# Total number of obstacles in the track: 7
# Episode:256 Score:790.1098901098788
# Track generation: 1142..1432 -> 290-tiles track
# Total number of obstacles in the track: 12
# Episode:257 Score:540.4844290657352
# Track generation: 1055..1327 -> 272-tiles track
# Total number of obstacles in the track: 7
# Episode:258 Score:590.0369003690009
# Track generation: 1158..1459 -> 301-tiles track
# Total number of obstacles in the track: 8
# Episode:259 Score:100.00000000000429
# Track generation: 1136..1424 -> 288-tiles track
# Total number of obstacles in the track: 6
# Episode:260 Score:414.4599303135771
# Track generation: 1145..1434 -> 289-tiles track
# Total number of obstacles in the track: 8
# Episode:261 Score:648.6111111110988
# Track generation: 1035..1304 -> 269-tiles track
# Total number of obstacles in the track: 7
# Episode:262 Score:775.3731343283429
# Track generation: 1349..1690 -> 341-tiles track
# Total number of obstacles in the track: 4
# Episode:263 Score:599.999999999991
# Track generation: 1167..1463 -> 296-tiles track
# Total number of obstacles in the track: 11
# Episode:264 Score:570.338983050835
# Track generation: 985..1242 -> 257-tiles track
# Total number of obstacles in the track: 3
# Episode:265 Score:814.0624999999867
# Track generation: 1216..1524 -> 308-tiles track
# Total number of obstacles in the track: 11
# Episode:266 Score:618.7296416937988
# Track generation: 1204..1509 -> 305-tiles track
# Total number of obstacles in the track: 10
# Episode:267 Score:436.1842105263041
# Track generation: 1154..1446 -> 292-tiles track
# Total number of obstacles in the track: 10
# Episode:268 Score:623.1958762886491
# Track generation: 1264..1584 -> 320-tiles track
# Total number of obstacles in the track: 9
# Episode:269 Score:398.432601880866
# Track generation: 1163..1459 -> 296-tiles track
# Total number of obstacles in the track: 10
# Episode:270 Score:676.2711864406672
# Track generation: 1141..1414 -> 273-tiles track
# Total number of obstacles in the track: 4
# Episode:271 Score:789.7058823529251
# Track generation: 1120..1404 -> 284-tiles track
# Total number of obstacles in the track: 9
# Episode:272 Score:659.1872791519347
# Track generation: 1187..1488 -> 301-tiles track
# Total number of obstacles in the track: 8
# Episode:273 Score:556.6666666666578
# Track generation: 1151..1443 -> 292-tiles track
# Total number of obstacles in the track: 9
# Episode:274 Score:697.2508591065158
# Track generation: 1032..1305 -> 273-tiles track
# Total number of obstacles in the track: 7
# Episode:275 Score:388.9705882352888
# Track generation: 1187..1488 -> 301-tiles track
# Total number of obstacles in the track: 9
# Episode:276 Score:226.66666666666572
# Track generation: 1315..1648 -> 333-tiles track
# Total number of obstacles in the track: 7
# Episode:277 Score:478.31325301203896
# Track generation: 1123..1408 -> 285-tiles track
# Total number of obstacles in the track: 6
# Episode:278 Score:448.59154929576465
# Track generation: 1086..1362 -> 276-tiles track
# Total number of obstacles in the track: 9
# Episode:279 Score:704.5454545454403
# Track generation: 1088..1364 -> 276-tiles track
# Total number of obstacles in the track: 7
# Episode:280 Score:668.1818181818048
# Track generation: 1168..1464 -> 296-tiles track
# Total number of obstacles in the track: 8
# Episode:281 Score:163.5593220339029
# Track generation: 1059..1330 -> 271-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1136..1424 -> 288-tiles track
# Total number of obstacles in the track: 7
# Episode:282 Score:675.7839721254262
# Track generation: 1153..1445 -> 292-tiles track
# Total number of obstacles in the track: 9
# Episode:283 Score:588.8316151202633
# Track generation: 1180..1483 -> 303-tiles track
# Total number of obstacles in the track: 9
# Episode:284 Score:505.2980132450264
# Track generation: 1150..1442 -> 292-tiles track
# Total number of obstacles in the track: 10
# Episode:285 Score:657.2164948453461
# Track generation: 1207..1513 -> 306-tiles track
# Total number of obstacles in the track: 8
# Episode:286 Score:469.67213114753054
# Track generation: 1158..1441 -> 283-tiles track
# Total number of obstacles in the track: 7
# Episode:287 Score:236.17021276595474
# Track generation: 997..1250 -> 253-tiles track
# Total number of obstacles in the track: 8
# Episode:288 Score:719.0476190476065
# Track generation: 1267..1588 -> 321-tiles track
# Total number of obstacles in the track: 11
# Episode:289 Score:196.87500000000472
# Track generation: 1081..1355 -> 274-tiles track
# Total number of obstacles in the track: 5
# Episode:290 Score:724.1758241758127
# Track generation: 1115..1405 -> 290-tiles track
# Total number of obstacles in the track: 9
# Episode:291 Score:254.8442906574437
# Track generation: 1128..1414 -> 286-tiles track
# Total number of obstacles in the track: 8
# Episode:292 Score:724.5614035087575
# Track generation: 1092..1373 -> 281-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1183..1483 -> 300-tiles track
# Total number of obstacles in the track: 6
# Episode:293 Score:508.86287625417276
# Track generation: 1180..1479 -> 299-tiles track
# Total number of obstacles in the track: 4
# Episode:294 Score:672.1476510066988
# Track generation: 1151..1443 -> 292-tiles track
# Total number of obstacles in the track: 8
# Episode:295 Score:470.1030927834969
# Track generation: 1298..1627 -> 329-tiles track
# Total number of obstacles in the track: 9
# Episode:296 Score:610.3658536585275
# Track generation: 1023..1283 -> 260-tiles track
# Total number of obstacles in the track: 7
# Episode:297 Score:537.6447876447717
# Track generation: 1140..1429 -> 289-tiles track
# Total number of obstacles in the track: 5
# Episode:298 Score:740.2777777777627
# Track generation: 1068..1339 -> 271-tiles track
# Total number of obstacles in the track: 10
# Episode:299 Score:581.4814814814681
# Track generation: 1247..1563 -> 316-tiles track
# Total number of obstacles in the track: 8
# Episode:300 Score:353.9682539682434
# Track generation: 1078..1351 -> 273-tiles track
# Total number of obstacles in the track: 5
# Episode:301 Score:774.9999999999844
# Track generation: 914..1152 -> 238-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1155..1448 -> 293-tiles track
# Total number of obstacles in the track: 9
# Episode:302 Score:669.8630136986163
# Track generation: 1262..1582 -> 320-tiles track
# Total number of obstacles in the track: 10
# Episode:303 Score:599.2163009404261
# Track generation: 1111..1393 -> 282-tiles track
# Total number of obstacles in the track: 9
# Episode:304 Score:657.2953736654714
# Track generation: 1065..1340 -> 275-tiles track
# Total number of obstacles in the track: 6
# Episode:305 Score:757.6642335766279
# Track generation: 1136..1425 -> 289-tiles track
# Total number of obstacles in the track: 5
# Episode:306 Score:534.0277777777663
# Track generation: 1092..1369 -> 277-tiles track
# Total number of obstacles in the track: 7
# Episode:307 Score:646.3768115941918
# Track generation: 1069..1345 -> 276-tiles track
# Total number of obstacles in the track: 8
# Episode:308 Score:750.9090909090767
# Track generation: 1194..1504 -> 310-tiles track
# Total number of obstacles in the track: 5
# Episode:309 Score:594.3365695792771
# Track generation: 1305..1635 -> 330-tiles track
# Total number of obstacles in the track: 11
# Episode:310 Score:581.1550151975604
# Track generation: 1268..1589 -> 321-tiles track
# Total number of obstacles in the track: 6
# Episode:311 Score:459.3749999999891
# Track generation: 1162..1457 -> 295-tiles track
# Total number of obstacles in the track: 10
# Episode:312 Score:592.5170068027123
# Track generation: 1075..1348 -> 273-tiles track
# Total number of obstacles in the track: 5
# Episode:313 Score:749.2647058823367
# Track generation: 1146..1437 -> 291-tiles track
# Total number of obstacles in the track: 6
# Episode:314 Score:594.8275862068816
# Track generation: 1159..1453 -> 294-tiles track
# Total number of obstacles in the track: 8
# Episode:315 Score:606.6552901023749
# Track generation: 1166..1462 -> 296-tiles track
# Total number of obstacles in the track: 8
# Episode:316 Score:93.22033898305423
# Track generation: 1147..1441 -> 294-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1129..1416 -> 287-tiles track
# Total number of obstacles in the track: 7
# Episode:317 Score:114.68531468531882
# Track generation: 1056..1324 -> 268-tiles track
# Total number of obstacles in the track: 8
# Episode:318 Score:623.970037453178
# Track generation: 1208..1514 -> 306-tiles track
# Total number of obstacles in the track: 8
# Episode:319 Score:352.45901639343
# Track generation: 1139..1428 -> 289-tiles track
# Total number of obstacles in the track: 9
# Episode:320 Score:736.8055555555394
# Track generation: 1175..1473 -> 298-tiles track
# Total number of obstacles in the track: 6
# Episode:321 Score:654.2087542087396
# Track generation: 1116..1399 -> 283-tiles track
# Total number of obstacles in the track: 7
# Episode:322 Score:555.673758865239
# Track generation: 1317..1650 -> 333-tiles track
# Total number of obstacles in the track: 9
# Episode:323 Score:496.3855421686651
# Track generation: 1340..1679 -> 339-tiles track
# Total number of obstacles in the track: 10
# Episode:324 Score:542.6035502958485
# Track generation: 1140..1429 -> 289-tiles track
# Total number of obstacles in the track: 10
# Episode:325 Score:659.7222222222088
# Track generation: 1120..1404 -> 284-tiles track
# Total number of obstacles in the track: 6
# Episode:326 Score:691.5194346289641
# Track generation: 1240..1554 -> 314-tiles track
# Total number of obstacles in the track: 9
# Episode:327 Score:431.46964856229033
# Track generation: 1135..1423 -> 288-tiles track
# Total number of obstacles in the track: 9
# Episode:328 Score:277.3519163763022
# Track generation: 1132..1419 -> 287-tiles track
# Total number of obstacles in the track: 7
# Episode:329 Score:554.1958041957939
# Track generation: 1211..1518 -> 307-tiles track
# Total number of obstacles in the track: 9
# Episode:330 Score:616.0130718954118
# Track generation: 1298..1626 -> 328-tiles track
# Total number of obstacles in the track: 7
# Episode:331 Score:436.08562691130817
# Track generation: 1236..1549 -> 313-tiles track
# Total number of obstacles in the track: 11
# Episode:332 Score:63.46153846153753
# Track generation: 1117..1400 -> 283-tiles track
# Total number of obstacles in the track: 9
# Episode:333 Score:825.1773049645274
# Track generation: 1075..1354 -> 279-tiles track
# Total number of obstacles in the track: 6
# Episode:334 Score:802.8776978417105
# Track generation: 1236..1549 -> 313-tiles track
# Total number of obstacles in the track: 10
# Episode:335 Score:300.64102564101574
# Track generation: 1088..1364 -> 276-tiles track
# Total number of obstacles in the track: 10
# Episode:336 Score:594.5454545454442
# Track generation: 1268..1589 -> 321-tiles track
# Total number of obstacles in the track: 9
# Episode:337 Score:428.12499999999585
# Track generation: 1160..1454 -> 294-tiles track
# Total number of obstacles in the track: 10
# Episode:338 Score:471.1604095563002
# Track generation: 1172..1469 -> 297-tiles track
# Total number of obstacles in the track: 9
# Episode:339 Score:427.70270270269526
# Track generation: 1279..1603 -> 324-tiles track
# Total number of obstacles in the track: 6
# Episode:340 Score:633.7461300309513
# Track generation: 1196..1499 -> 303-tiles track
# Total number of obstacles in the track: 11
# Episode:341 Score:700.9933774834342
# Track generation: 1135..1423 -> 288-tiles track
# Total number of obstacles in the track: 6
# Episode:342 Score:273.8675958188071
# Track generation: 1041..1305 -> 264-tiles track
# Total number of obstacles in the track: 8
# Episode:343 Score:766.3498098859177
# Track generation: 1143..1433 -> 290-tiles track
# Total number of obstacles in the track: 9
# Episode:344 Score:668.1660899653887
# Track generation: 1195..1498 -> 303-tiles track
# Total number of obstacles in the track: 8
# Episode:345 Score:505.9602649006524
# Track generation: 1110..1400 -> 290-tiles track
# Total number of obstacles in the track: 6
# Episode:346 Score:166.4359861591742
# Track generation: 1098..1377 -> 279-tiles track
# Total number of obstacles in the track: 9
# Episode:347 Score:487.7697841726526
# Track generation: 1156..1449 -> 293-tiles track
# Total number of obstacles in the track: 8
# Episode:348 Score:644.5205479451927
# Track generation: 1121..1411 -> 290-tiles track
# Total number of obstacles in the track: 8
# Episode:349 Score:520.0692041522412
# Track generation: 1195..1498 -> 303-tiles track
# Total number of obstacles in the track: 10
# Episode:350 Score:647.6821192052894
# Track generation: 1052..1319 -> 267-tiles track
# ...
# Track generation: 925..1160 -> 235-tiles track
# Total number of obstacles in the track: 8
# Episode:381 Score:857.2649572649425
# Track generation: 1145..1435 -> 290-tiles track
# Total number of obstacles in the track: 8
# Episode:382 Score:296.89550173009695
# Track generation: 1051..1323 -> 272-tiles track
# Total number of obstacles in the track: 6
# Episode:383 Score:390.7749077490758
# Track generation: 1141..1437 -> 296-tiles track
# Total number of obstacles in the track: 4
# Episode:384 Score:374.57627118643865
# Track generation: 1212..1519 -> 307-tiles track
# Total number of obstacles in the track: 10
# Episode:385 Score:595.0980392156738
# Track generation: 1151..1443 -> 292-tiles track
# Total number of obstacles in the track: 11
# Episode:386 Score:630.0687285223246
# Track generation: 1235..1548 -> 313-tiles track
# Total number of obstacles in the track: 10
# Episode:387 Score:474.9999999999941
# Track generation: 1170..1467 -> 297-tiles track
# Total number of obstacles in the track: 7
# Episode:388 Score:339.1891891891779
# Track generation: 1160..1454 -> 294-tiles track
# Total number of obstacles in the track: 6
# Episode:389 Score:234.47098976109453
# Track generation: 1122..1407 -> 285-tiles track
# Total number of obstacles in the track: 9
# Episode:390 Score:759.1549295774502
# Track generation: 1108..1393 -> 285-tiles track
# Total number of obstacles in the track: 8
# Episode:391 Score:833.0985915492786
# Track generation: 1111..1393 -> 282-tiles track
# Total number of obstacles in the track: 9
# Episode:392 Score:333.80782918149146
# Track generation: 987..1243 -> 256-tiles track
# Total number of obstacles in the track: 9
# Episode:393 Score:644.1176470588141
# Track generation: 1111..1393 -> 282-tiles track
# Total number of obstacles in the track: 8
# Episode:394 Score:621.8861209964299
# Track generation: 1141..1430 -> 289-tiles track
# Total number of obstacles in the track: 6
# Episode:395 Score:220.92222222221346
# Track generation: 1072..1349 -> 277-tiles track
# Total number of obstacles in the track: 11
# Episode:396 Score:30.434782608698043
# Track generation: 1196..1499 -> 303-tiles track
# Total number of obstacles in the track: 10
# Episode:397 Score:171.52317880795147
# Track generation: 1279..1603 -> 324-tiles track
# Total number of obstacles in the track: 12
# Episode:398 Score:406.3467492259987
# Track generation: 1104..1384 -> 280-tiles track
# Total number of obstacles in the track: 5
# Episode:399 Score:731.7204301075142
# Track generation: 1135..1423 -> 288-tiles track
# Total number of obstacles in the track: 8
# Episode:400 Score:543.2055749128793
# Track generation: 1288..1614 -> 326-tiles track
# Total number of obstacles in the track: 12
# Episode:401 Score:121.59230769231124
# Track generation: 1152..1444 -> 292-tiles track
# Total number of obstacles in the track: 9
# Episode:402 Score:709.106529209608
# Track generation: 1127..1413 -> 286-tiles track
# Total number of obstacles in the track: 9
# Episode:403 Score:797.3684210526152
# Track generation: 1212..1519 -> 307-tiles track
# Total number of obstacles in the track: 9
# Episode:404 Score:410.4575163398632
# Track generation: 1247..1563 -> 316-tiles track
# Total number of obstacles in the track: 8
# Episode:405 Score:579.3650793650681
# Track generation: 1140..1429 -> 289-tiles track
# Total number of obstacles in the track: 6
# Episode:406 Score:698.611111111096
# Track generation: 1235..1548 -> 313-tiles track
# Total number of obstacles in the track: 9
# Episode:407 Score:284.6153846153767
# Track generation: 1248..1564 -> 316-tiles track
# Total number of obstacles in the track: 10
# Episode:408 Score:357.14285714284676
# Track generation: 1060..1329 -> 269-tiles track
# Total number of obstacles in the track: 9
# Episode:409 Score:735.8208955223736
# Track generation: 1260..1582 -> 322-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1021..1284 -> 263-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1196..1499 -> 303-tiles track
# Total number of obstacles in the track: 10
# Episode:410 Score:598.3443708609177
# Track generation: 1130..1416 -> 286-tiles track
# Total number of obstacles in the track: 5
# Episode:411 Score:514.0350877192893
# Track generation: 1195..1498 -> 303-tiles track
# Total number of obstacles in the track: 4
# Episode:412 Score:591.7218543046263
# Track generation: 1085..1364 -> 279-tiles track
# Total number of obstacles in the track: 5
# Episode:413 Score:767.2661870503447
# Track generation: 975..1231 -> 256-tiles track
# Total number of obstacles in the track: 9
# Episode:414 Score:469.6078431372521
# Track generation: 1092..1374 -> 282-tiles track
# Total number of obstacles in the track: 10
# Episode:415 Score:611.2099644128049
# Track generation: 1164..1459 -> 295-tiles track
# Total number of obstacles in the track: 9
# Episode:416 Score:334.01360544216675
# Track generation: 1009..1265 -> 256-tiles track
# Total number of obstacles in the track: 8
# Episode:417 Score:695.0980392156702
# Track generation: 1093..1370 -> 277-tiles track
# Total number of obstacles in the track: 4
# Episode:418 Score:805.797101449265
# Track generation: 994..1247 -> 253-tiles track
# Total number of obstacles in the track: 7
# Episode:419 Score:738.8888888888787
# Track generation: 1127..1413 -> 286-tiles track
# Total number of obstacles in the track: 9
# Episode:420 Score:606.140350877179
# Track generation: 1175..1473 -> 298-tiles track
# Total number of obstacles in the track: 8
# Episode:421 Score:233.33333333332806
# Track generation: 1149..1440 -> 291-tiles track
# Total number of obstacles in the track: 9
# Episode:422 Score:687.931034482745
# Track generation: 1132..1421 -> 289-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1100..1381 -> 281-tiles track
# Total number of obstacles in the track: 6
# Episode:423 Score:507.14285714284546
# Track generation: 1075..1348 -> 273-tiles track
# Total number of obstacles in the track: 7
# Episode:424 Score:674.9999999999856
# Track generation: 1147..1437 -> 290-tiles track
# Total number of obstacles in the track: 8
# Episode:425 Score:502.4221453287107
# Track generation: 1027..1295 -> 268-tiles track
# Total number of obstacles in the track: 6
# Episode:426 Score:737.6404494381918
# Track generation: 1086..1366 -> 280-tiles track
# Total number of obstacles in the track: 8
# Episode:427 Score:527.2401433691699
# Track generation: 922..1162 -> 240-tiles track
# Total number of obstacles in the track: 9
# Episode:428 Score:720.5020920501943
# Track generation: 1095..1373 -> 278-tiles track
# Total number of obstacles in the track: 6
# Episode:429 Score:514.8014440433121
# Track generation: 1264..1584 -> 320-tiles track
# Total number of obstacles in the track: 11
# Episode:430 Score:589.9686520376054
# Track generation: 1260..1579 -> 319-tiles track
# Total number of obstacles in the track: 12
# Episode:431 Score:588.9937106918098
# Track generation: 1024..1284 -> 260-tiles track
# Total number of obstacles in the track: 9
# Episode:432 Score:768.9189189189024
# Track generation: 892..1127 -> 235-tiles track
# Total number of obstacles in the track: 6
# Episode:433 Score:802.9914529914378
# Track generation: 1188..1489 -> 301-tiles track
# Total number of obstacles in the track: 5
# Episode:434 Score:599.9999999999899
# Track generation: 1227..1538 -> 311-tiles track
# Total number of obstacles in the track: 7
# Episode:435 Score:314.51612903224924
# Track generation: 1380..1729 -> 349-tiles track
# Total number of obstacles in the track: 10
# Episode:436 Score:121.26436781609672
# Track generation: 1190..1492 -> 302-tiles track
# Total number of obstacles in the track: 8
# Episode:437 Score:357.97342192690195
# Track generation: 1359..1703 -> 344-tiles track
# Total number of obstacles in the track: 10
# Episode:438 Score:340.23323615159444
# Track generation: 1132..1419 -> 287-tiles track
# Total number of obstacles in the track: 6
# Episode:439 Score:759.0909090908962
# Track generation: 1231..1543 -> 312-tiles track
# Total number of obstacles in the track: 11
# Episode:440 Score:531.350482315106
# Track generation: 1239..1552 -> 313-tiles track
# Total number of obstacles in the track: 11
# Episode:441 Score:178.84615384615856
# Track generation: 1084..1364 -> 280-tiles track
# Total number of obstacles in the track: 5
# Episode:442 Score:641.9354838709561
# Track generation: 1107..1389 -> 282-tiles track
# Total number of obstacles in the track: 10
# Episode:443 Score:572.2419928825525
# Track generation: 1296..1624 -> 328-tiles track
# Total number of obstacles in the track: 13
# Episode:444 Score:331.19266055045034
# Track generation: 1100..1379 -> 279-tiles track
# Total number of obstacles in the track: 10
# Episode:445 Score:605.3956834532243
# Track generation: 1097..1380 -> 283-tiles track
# Total number of obstacles in the track: 10
# Episode:446 Score:584.0425531914788
# Track generation: 1129..1421 -> 292-tiles track
# Total number of obstacles in the track: 7
# Episode:447 Score:636.9415807560022
# Track generation: 1108..1389 -> 281-tiles track
# Total number of obstacles in the track: 6
# Episode:448 Score:717.8571428571287
# Track generation: 1104..1384 -> 280-tiles track
# Total number of obstacles in the track: 5
# Episode:449 Score:731.7204301075135
# Track generation: 1156..1449 -> 293-tiles track
# Total number of obstacles in the track: 9
# Episode:450 Score:692.4657534246451
# Track generation: 1100..1379 -> 279-tiles track
# Total number of obstacles in the track: 7
# Episode:451 Score:556.4748201438726
# Track generation: 978..1227 -> 249-tiles track
# Total number of obstacles in the track: 3
# Episode:452 Score:827.4193548386951
# Track generation: 1195..1498 -> 303-tiles track
# Total number of obstacles in the track: 8
# Episode:453 Score:650.9933774834343
# Track generation: 1223..1533 -> 310-tiles track
# Total number of obstacles in the track: 11
# Episode:454 Score:233.33333333332658
# Track generation: 1087..1363 -> 276-tiles track
# Total number of obstacles in the track: 8
# Episode:455 Score:602.7272727272588
# Track generation: 1047..1317 -> 270-tiles track
# Total number of obstacles in the track: 7
# Episode:456 Score:537.73234200743
# Track generation: 1093..1375 -> 282-tiles track
# Total number of obstacles in the track: 8
# Episode:457 Score:398.0427046263335
# Track generation: 1260..1579 -> 319-tiles track
# Total number of obstacles in the track: 9
# Episode:458 Score:513.8364779874125
# Track generation: 1159..1453 -> 294-tiles track
# Total number of obstacles in the track: 7
# Episode:459 Score:658.873720136506
# Track generation: 1096..1376 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1167..1463 -> 296-tiles track
# Total number of obstacles in the track: 9
# Episode:460 Score:562.7118644067681
# Track generation: 1164..1459 -> 295-tiles track
# Total number of obstacles in the track: 8
# Episode:461 Score:621.0884353741397
# Track generation: 1187..1488 -> 301-tiles track
# Total number of obstacles in the track: 10
# Episode:462 Score:546.6666666666525
# Track generation: 1045..1314 -> 269-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1143..1433 -> 290-tiles track
# Total number of obstacles in the track: 9
# Episode:463 Score:448.6159169550083
# Track generation: 1214..1522 -> 308-tiles track
# Total number of obstacles in the track: 8
# Episode:464 Score:644.7882736156238
# Track generation: 1307..1638 -> 331-tiles track
# Total number of obstacles in the track: 7
# Episode:465 Score:492.4242424242302
# Track generation: 1085..1360 -> 275-tiles track
# Total number of obstacles in the track: 8
# Episode:466 Score:713.8686131386717
# Track generation: 1384..1737 -> 353-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1146..1437 -> 291-tiles track
# Total number of obstacles in the track: 8
# Episode:467 Score:587.9310344827455
# Track generation: 1132..1419 -> 287-tiles track
# Total number of obstacles in the track: 8
# Episode:468 Score:339.51048951048
# Track generation: 1059..1335 -> 276-tiles track
# Total number of obstacles in the track: 8
# Episode:469 Score:60.00000000000449
# Track generation: 1039..1303 -> 264-tiles track
# Total number of obstacles in the track: 8
# Episode:470 Score:666.3498098859168
# Track generation: 1188..1489 -> 301-tiles track
# Total number of obstacles in the track: 9
# Episode:471 Score:413.33333333332325
# Track generation: 1161..1455 -> 294-tiles track
# Total number of obstacles in the track: 6
# Episode:472 Score:484.81228668940736
# Track generation: 1208..1514 -> 306-tiles track
# Total number of obstacles in the track: 9
# Episode:473 Score:470.4918032786776
# Track generation: 1268..1589 -> 321-tiles track
# Total number of obstacles in the track: 7
# Episode:474 Score:481.2499999999894
# Track generation: 1103..1383 -> 280-tiles track
# Total number of obstacles in the track: 9
# Episode:475 Score:549.1039426523165
# Track generation: 1055..1323 -> 268-tiles track
# Total number of obstacles in the track: 8
# Episode:476 Score:743.8202247190904
# Track generation: 1064..1333 -> 269-tiles track
# Total number of obstacles in the track: 8
# Episode:477 Score:382.08955223879155
# Track generation: 1200..1505 -> 305-tiles track
# Total number of obstacles in the track: 11
# Episode:478 Score:388.8157894736736
# Track generation: 1304..1634 -> 330-tiles track
# Total number of obstacles in the track: 5
# Episode:479 Score:188.7537993921024
# Track generation: 1315..1648 -> 333-tiles track
# Total number of obstacles in the track: 8
# Episode:480 Score:634.9397590361372
# Track generation: 1114..1397 -> 283-tiles track
# Total number of obstacles in the track: 5
# Episode:481 Score:640.4255319148817
# Track generation: 1172..1469 -> 297-tiles track
# Total number of obstacles in the track: 9
# Episode:482 Score:464.1891891891783
# Track generation: 1075..1353 -> 278-tiles track
# Total number of obstacles in the track: 7
# Episode:483 Score:716.4259927797746
# Track generation: 1027..1293 -> 266-tiles track
# Total number of obstacles in the track: 5
# Episode:484 Score:838.679245283009
# Track generation: 1187..1488 -> 301-tiles track
# Total number of obstacles in the track: 10
# Episode:485 Score:556.6666666666518
# Track generation: 1119..1403 -> 284-tiles track
# Total number of obstacles in the track: 6
# Episode:486 Score:704.5936395759591
# Track generation: 1322..1657 -> 335-tiles track
# Total number of obstacles in the track: 8
# Episode:487 Score:490.71856287424146
# Track generation: 1274..1597 -> 323-tiles track
# Total number of obstacles in the track: 10
# Episode:488 Score:514.5962732919191
# Track generation: 1197..1500 -> 303-tiles track
# Total number of obstacles in the track: 9
# Episode:489 Score:498.34437086092134
# Track generation: 1224..1534 -> 310-tiles track
# Total number of obstacles in the track: 9
# Episode:490 Score:481.06796116503796
# Track generation: 1120..1404 -> 284-tiles track
# Total number of obstacles in the track: 7
# Episode:491 Score:737.4558303886806
# Track generation: 1168..1464 -> 296-tiles track
# Total number of obstacles in the track: 11
# Episode:492 Score:619.4915254237173
# Track generation: 1179..1478 -> 299-tiles track
# Total number of obstacles in the track: 10
# Episode:493 Score:436.912751677842
# Track generation: 1076..1349 -> 273-tiles track
# Total number of obstacles in the track: 9
# Episode:494 Score:433.0882352941048
# Track generation: 1039..1303 -> 264-tiles track
# Total number of obstacles in the track: 9
# Episode:495 Score:577.7566539923854
# Track generation: 1167..1463 -> 296-tiles track
# Total number of obstacles in the track: 8
# Episode:496 Score:576.2711864406654
# Track generation: 1044..1311 -> 267-tiles track
# Total number of obstacles in the track: 8
# Episode:497 Score:748.4962406014876
# Track generation: 1206..1512 -> 306-tiles track
# Total number of obstacles in the track: 9
# Episode:498 Score:650.8196721311366
# Track generation: 958..1208 -> 250-tiles track
# Total number of obstacles in the track: 6
# Episode:499 Score:438.1526104417558
# Track generation: 1351..1693 -> 342-tiles track
# Total number of obstacles in the track: 9
# Episode:500 Score:136.71788856305247
# Number of tiles: 201.932
# Time taken: 19.868759999999725

# %%
# To calculate number of tiles covered, time taken and collision/obstacle ratio in obstacle variant environment
episodes = 500
frames = []

ratios=0
tiles=0
times=0

for episode in range(1, episodes+1):
    obs = eval_env.reset()  #state = env.reset()
    done = False
    score = 0
    
    info={}
    
    while not done:
        # frames.append(env.render(mode='rgb_array'))
        action , _ = best_model.predict(obs.copy()) 
        obs, reward, done, info = eval_env.step(action) 
        score += reward
    
    tiles+=eval_env.tile_visited_count
    times+=eval_env.t
    ratios+=info['num_collisions']/info['num_obstacles']
    
    print("Episode:{} Score:{}".format(episode,score))
    
print("Number of tiles:",tiles/500)
print("Time taken:",times/500)
print("Ratio:",ratios/500)
eval_env.close()
# Out:
# Track generation: 1143..1442 -> 299-tiles track
# Total number of obstacles in the track: 9
# Episode:1 Score:437.5838926174462
# Track generation: 1087..1369 -> 282-tiles track
# Total number of obstacles in the track: 8
# Episode:2 Score:537.0106761565746
# Track generation: 964..1212 -> 248-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1176..1474 -> 298-tiles track
# Total number of obstacles in the track: 5
# Episode:3 Score:406.06060606060055
# Track generation: 1283..1608 -> 325-tiles track
# Total number of obstacles in the track: 9
# Episode:4 Score:489.5061728395013
# Track generation: 1217..1526 -> 309-tiles track
# Total number of obstacles in the track: 9
# Episode:5 Score:424.6753246753151
# Track generation: 1096..1374 -> 278-tiles track
# Total number of obstacles in the track: 8
# Episode:6 Score:518.411552346558
# Track generation: 1198..1501 -> 303-tiles track
# Total number of obstacles in the track: 9
# Episode:7 Score:458.9403973509901
# Track generation: 1159..1453 -> 294-tiles track
# Total number of obstacles in the track: 8
# Episode:8 Score:568.9419795221734
# Track generation: 957..1205 -> 248-tiles track
# Total number of obstacles in the track: 8
# Episode:9 Score:653.0364372469488
# Track generation: 1181..1480 -> 299-tiles track
# Total number of obstacles in the track: 7
# Episode:10 Score:540.9395973154282
# Track generation: 979..1234 -> 255-tiles track
# Total number of obstacles in the track: 9
# Episode:11 Score:504.7244094488143
# Track generation: 1320..1654 -> 334-tiles track
# Total number of obstacles in the track: 9
# Episode:12 Score:521.6216216216134
# Track generation: 1067..1338 -> 271-tiles track
# Total number of obstacles in the track: 6
# Episode:13 Score:422.22222222221757
# Track generation: 1067..1338 -> 271-tiles track
# Total number of obstacles in the track: 8
# Episode:14 Score:561.1111111111009
# Track generation: 1207..1513 -> 306-tiles track
# Total number of obstacles in the track: 6
# Episode:15 Score:515.573770491793
# Track generation: 1106..1396 -> 290-tiles track
# Total number of obstacles in the track: 6
# Episode:16 Score:521.2802768166001
# Track generation: 1296..1628 -> 332-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1047..1319 -> 272-tiles track
# Total number of obstacles in the track: 4
# Episode:17 Score:756.0885608855995
# Track generation: 1245..1560 -> 315-tiles track
# Total number of obstacles in the track: 11
# Episode:18 Score:511.46496815285377
# Track generation: 1232..1544 -> 312-tiles track
# Total number of obstacles in the track: 9
# Episode:19 Score:239.06752411575965
# Track generation: 1120..1408 -> 288-tiles track
# Total number of obstacles in the track: 9
# Episode:20 Score:518.9895470383166
# Track generation: 1225..1536 -> 311-tiles track
# Total number of obstacles in the track: 9
# Episode:21 Score:353.2258064516057
# Track generation: 1077..1357 -> 280-tiles track
# Total number of obstacles in the track: 5
# Episode:22 Score:695.6989247311703
# Track generation: 1322..1664 -> 342-tiles track
# Total number of obstacles in the track: 11
# Episode:23 Score:410.26392961876206
# Track generation: 1035..1297 -> 262-tiles track
# Total number of obstacles in the track: 6
# Episode:24 Score:585.4406130268087
# Track generation: 1297..1626 -> 329-tiles track
# Total number of obstacles in the track: 6
# Episode:25 Score:318.292682926819
# Track generation: 1294..1621 -> 327-tiles track
# Total number of obstacles in the track: 11
# Episode:26 Score:352.14723926380157
# Track generation: 1055..1331 -> 276-tiles track
# Total number of obstacles in the track: 9
# Episode:27 Score:315.45454545454305
# Track generation: 1202..1507 -> 305-tiles track
# Total number of obstacles in the track: 11
# Episode:28 Score:408.55263157894063
# Track generation: 863..1087 -> 224-tiles track
# Total number of obstacles in the track: 6
# Episode:29 Score:680.2690582959497
# Track generation: 1227..1538 -> 311-tiles track
# Total number of obstacles in the track: 8
# Episode:30 Score:632.2580645161211
# Track generation: 1317..1652 -> 335-tiles track
# Total number of obstacles in the track: 9
# Episode:31 Score:507.78443113771493
# Track generation: 1115..1402 -> 287-tiles track
# Total number of obstacles in the track: 9
# Episode:32 Score:623.7762237762134
# Track generation: 1168..1464 -> 296-tiles track
# Total number of obstacles in the track: 9
# Episode:33 Score:374.5762711864308
# Track generation: 1056..1324 -> 268-tiles track
# Total number of obstacles in the track: 8
# Episode:34 Score:626.5917602996166
# Track generation: 1204..1509 -> 305-tiles track
# Total number of obstacles in the track: 10
# Episode:35 Score:518.4210526315692
# Track generation: 1260..1579 -> 319-tiles track
# Total number of obstacles in the track: 11
# Episode:36 Score:242.76729559748924
# Track generation: 1100..1379 -> 279-tiles track
# Total number of obstacles in the track: 9
# Episode:37 Score:522.302158273369
# Track generation: 1185..1485 -> 300-tiles track
# Total number of obstacles in the track: 11
# Episode:38 Score:478.59531772574496
# Track generation: 1034..1296 -> 262-tiles track
# Total number of obstacles in the track: 5
# Episode:39 Score:704.5977011494151
# Track generation: 1076..1352 -> 276-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1132..1419 -> 287-tiles track
# Total number of obstacles in the track: 4
# Episode:40 Score:581.8181818181723
# Track generation: 1292..1619 -> 327-tiles track
# Total number of obstacles in the track: 13
# Episode:41 Score:309.20245398772624
# Track generation: 1275..1598 -> 323-tiles track
# Total number of obstacles in the track: 8
# Episode:42 Score:549.0683229813569
# Track generation: 1056..1324 -> 268-tiles track
# Total number of obstacles in the track: 6
# Episode:43 Score:626.5917602996151
# Track generation: 1092..1377 -> 285-tiles track
# Total number of obstacles in the track: 10
# Episode:44 Score:483.8028169014006
# Track generation: 1127..1413 -> 286-tiles track
# Total number of obstacles in the track: 7
# Episode:45 Score:542.1052631578808
# Track generation: 1104..1384 -> 280-tiles track
# Total number of obstacles in the track: 9
# Episode:46 Score:531.0035842293815
# Track generation: 1131..1430 -> 299-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1195..1498 -> 303-tiles track
# Total number of obstacles in the track: 10
# Episode:47 Score:568.874172185424
# Track generation: 1155..1448 -> 293-tiles track
# Total number of obstacles in the track: 10
# Episode:48 Score:509.5890410958826
# Track generation: 1317..1650 -> 333-tiles track
# Total number of obstacles in the track: 10
# Episode:49 Score:396.3855421686672
# Track generation: 1180..1479 -> 299-tiles track
# Total number of obstacles in the track: 10
# Episode:50 Score:510.73825503354874
# Track generation: 1170..1467 -> 297-tiles track
# Total number of obstacles in the track: 7
# Episode:51 Score:660.1351351351229
# Track generation: 1022..1282 -> 260-tiles track
# Total number of obstacles in the track: 8
# Episode:52 Score:359.6525096524979
# Track generation: 1230..1542 -> 312-tiles track
# Total number of obstacles in the track: 11
# Episode:53 Score:156.91318327974258
# Track generation: 1018..1278 -> 260-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1126..1412 -> 286-tiles track
# Total number of obstacles in the track: 6
# Episode:54 Score:523.6842105263029
# Track generation: 1251..1568 -> 317-tiles track
# Total number of obstacles in the track: 9
# Episode:55 Score:523.4177215189774
# Track generation: 1202..1507 -> 305-tiles track
# Total number of obstacles in the track: 6
# Episode:56 Score:554.6052631578831
# Track generation: 1265..1592 -> 327-tiles track
# Total number of obstacles in the track: 10
# Episode:57 Score:388.95705521471695
# Track generation: 1049..1315 -> 266-tiles track
# Total number of obstacles in the track: 7
# Episode:58 Score:647.1698113207436
# Track generation: 1345..1685 -> 340-tiles track
# Total number of obstacles in the track: 6
# Episode:59 Score:274.7787610619383
# Track generation: 929..1167 -> 238-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1059..1328 -> 269-tiles track
# Total number of obstacles in the track: 7
# Episode:60 Score:261.19402985073623
# Track generation: 981..1236 -> 255-tiles track
# Total number of obstacles in the track: 6
# Episode:61 Score:541.732283464555
# Track generation: 1220..1529 -> 309-tiles track
# Total number of obstacles in the track: 11
# Episode:62 Score:300.00000000000176
# Track generation: 1062..1332 -> 270-tiles track
# Total number of obstacles in the track: 7
# Episode:63 Score:669.5167286245228
# Track generation: 1148..1439 -> 291-tiles track
# Total number of obstacles in the track: 6
# Episode:64 Score:446.5517241379186
# Track generation: 983..1235 -> 252-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1106..1387 -> 281-tiles track
# Total number of obstacles in the track: 10
# Episode:65 Score:260.7142857142904
# Track generation: 1068..1339 -> 271-tiles track
# Total number of obstacles in the track: 9
# Episode:66 Score:540.7407407407301
# Track generation: 1285..1611 -> 326-tiles track
# Total number of obstacles in the track: 9
# Episode:67 Score:378.4615384615285
# Track generation: 1224..1534 -> 310-tiles track
# Total number of obstacles in the track: 5
# Episode:68 Score:595.7928802588875
# Track generation: 1095..1373 -> 278-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1209..1515 -> 306-tiles track
# Total number of obstacles in the track: 11
# Episode:69 Score:413.11475409834975
# Track generation: 1167..1463 -> 296-tiles track
# Total number of obstacles in the track: 7
# Episode:70 Score:588.1355932203277
# Track generation: 1215..1523 -> 308-tiles track
# Total number of obstacles in the track: 10
# Episode:71 Score:459.12052117263244
# Track generation: 1292..1619 -> 327-tiles track
# Total number of obstacles in the track: 10
# Episode:72 Score:432.82208588956246
# Track generation: 1099..1378 -> 279-tiles track
# Total number of obstacles in the track: 9
# Episode:73 Score:547.8417266186935
# Track generation: 1179..1478 -> 299-tiles track
# Total number of obstacles in the track: 9
# Episode:74 Score:571.1409395973064
# Track generation: 1107..1388 -> 281-tiles track
# Total number of obstacles in the track: 9
# Episode:75 Score:464.28571428570274
# Track generation: 1209..1519 -> 310-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1233..1544 -> 311-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1234..1555 -> 321-tiles track
# Total number of obstacles in the track: 9
# Episode:76 Score:462.4999999999933
# Track generation: 1232..1553 -> 321-tiles track
# Total number of obstacles in the track: 10
# Episode:77 Score:456.249999999991
# Track generation: 1214..1522 -> 308-tiles track
# Total number of obstacles in the track: 7
# Episode:78 Score:433.0618892508097
# Track generation: 1151..1450 -> 299-tiles track
# Total number of obstacles in the track: 10
# Episode:79 Score:460.40268456374923
# Track generation: 1213..1529 -> 316-tiles track
# Total number of obstacles in the track: 10
# Episode:80 Score:329.36507936507337
# Track generation: 1252..1569 -> 317-tiles track
# Total number of obstacles in the track: 9
# Episode:81 Score:564.5569620253061
# Track generation: 1040..1304 -> 264-tiles track
# Total number of obstacles in the track: 7
# Episode:82 Score:538.7832699619646
# Track generation: 1128..1414 -> 286-tiles track
# Total number of obstacles in the track: 7
# Episode:83 Score:583.3333333333192
# Track generation: 1121..1408 -> 287-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1048..1319 -> 271-tiles track
# Total number of obstacles in the track: 9
# Episode:84 Score:581.4814814814697
# Track generation: 1224..1534 -> 310-tiles track
# Total number of obstacles in the track: 8
# Episode:85 Score:304.854368932029
# Track generation: 1140..1429 -> 289-tiles track
# Total number of obstacles in the track: 5
# Episode:86 Score:516.6666666666537
# Track generation: 1114..1400 -> 286-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1052..1319 -> 267-tiles track
# Total number of obstacles in the track: 6
# Episode:87 Score:745.8646616541205
# Track generation: 1045..1313 -> 268-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1131..1418 -> 287-tiles track
# Total number of obstacles in the track: 4
# Episode:88 Score:728.6713286713158
# Track generation: 1122..1412 -> 290-tiles track
# Total number of obstacles in the track: 11
# Episode:89 Score:452.07612456746733
# Track generation: 1239..1553 -> 314-tiles track
# Total number of obstacles in the track: 10
# Episode:90 Score:479.392971245998
# Track generation: 1022..1283 -> 261-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1123..1408 -> 285-tiles track
# Total number of obstacles in the track: 8
# Episode:91 Score:607.7464788732282
# Track generation: 1158..1462 -> 304-tiles track
# Total number of obstacles in the track: 7
# Episode:92 Score:456.76567656764973
# Track generation: 1313..1645 -> 332-tiles track
# Total number of obstacles in the track: 9
# Episode:93 Score:454.22960725074336
# Track generation: 1000..1254 -> 254-tiles track
# Total number of obstacles in the track: 4
# Episode:94 Score:626.0869565217315
# Track generation: 1259..1578 -> 319-tiles track
# Total number of obstacles in the track: 8
# Episode:95 Score:569.8113207547051
# Track generation: 1316..1655 -> 339-tiles track
# Total number of obstacles in the track: 7
# Episode:96 Score:429.5857988165605
# Track generation: 1086..1367 -> 281-tiles track
# Total number of obstacles in the track: 3
# Episode:97 Score:692.8571428571306
# Track generation: 988..1238 -> 250-tiles track
# Total number of obstacles in the track: 8
# Episode:98 Score:731.3253012048077
# Track generation: 1072..1344 -> 272-tiles track
# Total number of obstacles in the track: 8
# Episode:99 Score:510.5166051660425
# Track generation: 1152..1444 -> 292-tiles track
# Total number of obstacles in the track: 9
# Episode:100 Score:563.2302405498177
# Track generation: 1066..1341 -> 275-tiles track
# Total number of obstacles in the track: 8
# Episode:101 Score:622.6277372262693
# Track generation: 1070..1341 -> 271-tiles track
# Total number of obstacles in the track: 9
# Episode:102 Score:551.8518518518423
# Track generation: 1231..1543 -> 312-tiles track
# Total number of obstacles in the track: 5
# Episode:103 Score:607.3954983922708
# Track generation: 1168..1464 -> 296-tiles track
# Total number of obstacles in the track: 7
# Episode:104 Score:598.3050847457519
# Track generation: 1020..1279 -> 259-tiles track
# Total number of obstacles in the track: 8
# Episode:105 Score:613.1782945736343
# Track generation: 1080..1359 -> 279-tiles track
# Total number of obstacles in the track: 9
# Episode:106 Score:489.9280575539446
# Track generation: 1275..1598 -> 323-tiles track
# Total number of obstacles in the track: 10
# Episode:107 Score:280.4347826086978
# Track generation: 1099..1381 -> 282-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1063..1333 -> 270-tiles track
# Total number of obstacles in the track: 6
# Episode:108 Score:478.2527881040852
# Track generation: 1123..1408 -> 285-tiles track
# Total number of obstacles in the track: 6
# Episode:109 Score:433.0985915492871
# Track generation: 1228..1539 -> 311-tiles track
# Total number of obstacles in the track: 9
# Episode:110 Score:548.3870967741868
# Track generation: 1151..1443 -> 292-tiles track
# Total number of obstacles in the track: 6
# Episode:111 Score:602.577319587615
# Track generation: 1171..1468 -> 297-tiles track
# Total number of obstacles in the track: 8
# Episode:112 Score:548.6486486486396
# Track generation: 1212..1519 -> 307-tiles track
# Total number of obstacles in the track: 8
# Episode:113 Score:501.3071895424727
# Track generation: 1270..1592 -> 322-tiles track
# Total number of obstacles in the track: 10
# Episode:114 Score:454.51713395637773
# Track generation: 1248..1564 -> 316-tiles track
# Total number of obstacles in the track: 8
# Episode:115 Score:465.0793650793566
# Track generation: 1096..1374 -> 278-tiles track
# Total number of obstacles in the track: 8
# Episode:116 Score:572.0216606498078
# Track generation: 1119..1403 -> 284-tiles track
# Total number of obstacles in the track: 8
# Episode:117 Score:556.7137809187185
# Track generation: 1154..1447 -> 293-tiles track
# Total number of obstacles in the track: 8
# Episode:118 Score:442.4657534246514
# Track generation: 1171..1468 -> 297-tiles track
# Total number of obstacles in the track: 8
# Episode:119 Score:562.1621621621529
# Track generation: 1139..1428 -> 289-tiles track
# Total number of obstacles in the track: 7
# Episode:120 Score:544.4444444444345
# Track generation: 1061..1339 -> 278-tiles track
# Total number of obstacles in the track: 3
# Episode:121 Score:668.953068592047
# Track generation: 1006..1269 -> 263-tiles track
# Total number of obstacles in the track: 6
# Episode:122 Score:659.1603053435015
# Track generation: 1161..1455 -> 294-tiles track
# Total number of obstacles in the track: 5
# Episode:123 Score:575.7679180887249
# Track generation: 1156..1448 -> 292-tiles track
# Total number of obstacles in the track: 9
# Episode:124 Score:568.2130584192322
# Track generation: 1207..1513 -> 306-tiles track
# Total number of obstacles in the track: 10
# Episode:125 Score:459.8360655737624
# Track generation: 1114..1397 -> 283-tiles track
# Total number of obstacles in the track: 7
# Episode:126 Score:534.751773049634
# Track generation: 1114..1405 -> 291-tiles track
# Total number of obstacles in the track: 5
# Episode:127 Score:612.0689655172287
# Track generation: 1332..1669 -> 337-tiles track
# Total number of obstacles in the track: 10
# Episode:128 Score:334.52380952379883
# Track generation: 1019..1278 -> 259-tiles track
# Total number of obstacles in the track: 4
# Episode:129 Score:760.465116279062
# Track generation: 1102..1380 -> 278-tiles track
# Total number of obstacles in the track: 3
# Episode:130 Score:751.9855595667776
# Track generation: 1065..1342 -> 277-tiles track
# Total number of obstacles in the track: 6
# Episode:131 Score:682.6086956521652
# Track generation: 1123..1410 -> 287-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1204..1509 -> 305-tiles track
# Total number of obstacles in the track: 7
# Episode:132 Score:580.9210526315684
# Track generation: 1199..1503 -> 304-tiles track
# Total number of obstacles in the track: 7
# Exception ignored in: <function Viewer.__del__ at 0x15fc738b0>
# Traceback (most recent call last):
#   File "/Users/PrishitaRay1/opt/anaconda3/lib/python3.9/site-packages/gym/envs/classic_control/rendering.py", line 185, in __del__
#     self.close()
#   File "/Users/PrishitaRay1/opt/anaconda3/lib/python3.9/site-packages/gym/envs/classic_control/rendering.py", line 99, in close
#     if self.isopen and sys.meta_path:
# AttributeError: 'Viewer' object has no attribute 'isopen'
# Episode:133 Score:383.16831683167396
# Track generation: 1059..1328 -> 269-tiles track
# Total number of obstacles in the track: 6
# Episode:134 Score:694.7761194029724
# Track generation: 945..1191 -> 246-tiles track
# Total number of obstacles in the track: 5
# Episode:135 Score:687.755102040801
# Track generation: 1224..1534 -> 310-tiles track
# Total number of obstacles in the track: 8
# Episode:136 Score:482.5242718446499
# Track generation: 1128..1414 -> 286-tiles track
# Total number of obstacles in the track: 8
# Episode:137 Score:636.842105263145
# Track generation: 1151..1443 -> 292-tiles track
# Total number of obstacles in the track: 5
# Episode:138 Score:638.8316151202632
# Track generation: 1261..1581 -> 320-tiles track
# Total number of obstacles in the track: 8
# Episode:139 Score:492.4764890282034
# Track generation: 1064..1333 -> 269-tiles track
# Total number of obstacles in the track: 6
# Episode:140 Score:663.4328358208817
# Track generation: 1287..1613 -> 326-tiles track
# Total number of obstacles in the track: 11
# Episode:141 Score:377.6923076923047
# Track generation: 1117..1400 -> 283-tiles track
# Total number of obstacles in the track: 9
# Episode:142 Score:637.5886524822611
# Track generation: 1057..1325 -> 268-tiles track
# Total number of obstacles in the track: 4
# Episode:143 Score:712.7340823969924
# Track generation: 1109..1396 -> 287-tiles track
# Total number of obstacles in the track: 9
# Episode:144 Score:543.3566433566342
# Track generation: 944..1184 -> 240-tiles track
# Total number of obstacles in the track: 6
# Episode:145 Score:715.899581589944
# Track generation: 1277..1601 -> 324-tiles track
# Total number of obstacles in the track: 10
# Episode:146 Score:478.9473684210453
# Track generation: 1202..1514 -> 312-tiles track
# Total number of obstacles in the track: 7
# Episode:147 Score:424.11575562699994
# Track generation: 1132..1419 -> 287-tiles track
# Total number of obstacles in the track: 5
# Episode:148 Score:556.2937062936962
# Track generation: 1196..1499 -> 303-tiles track
# Total number of obstacles in the track: 10
# Episode:149 Score:592.0529801324436
# Track generation: 1148..1439 -> 291-tiles track
# Total number of obstacles in the track: 6
# Episode:150 Score:627.5862068965388
# Track generation: 1192..1494 -> 302-tiles track
# Total number of obstacles in the track: 8
# Episode:151 Score:457.80730897009437
# Track generation: 1139..1428 -> 289-tiles track
# Total number of obstacles in the track: 6
# Episode:152 Score:649.9999999999868
# Track generation: 1212..1519 -> 307-tiles track
# Total number of obstacles in the track: 8
# Episode:153 Score:520.9150326797294
# Track generation: 1176..1474 -> 298-tiles track
# Total number of obstacles in the track: 9
# Episode:154 Score:473.40067340066133
# Track generation: 1169..1465 -> 296-tiles track
# Total number of obstacles in the track: 7
# Episode:155 Score:520.3389830508363
# Track generation: 964..1219 -> 255-tiles track
# Total number of obstacles in the track: 6
# Episode:156 Score:309.4488188976401
# Track generation: 1311..1643 -> 332-tiles track
# Total number of obstacles in the track: 5
# Episode:157 Score:603.9274924471151
# Track generation: 1031..1293 -> 262-tiles track
# Total number of obstacles in the track: 9
# Episode:158 Score:558.8122605363856
# Track generation: 1138..1427 -> 289-tiles track
# Total number of obstacles in the track: 7
# Episode:159 Score:499.30555555554474
# Track generation: 1053..1320 -> 267-tiles track
# Total number of obstacles in the track: 8
# Episode:160 Score:644.3609022556232
# Track generation: 1351..1693 -> 342-tiles track
# Total number of obstacles in the track: 5
# Episode:161 Score:336.51026392960966
# Track generation: 1276..1598 -> 322-tiles track
# Total number of obstacles in the track: 8
# Episode:162 Score:311.2149532710182
# Track generation: 1070..1342 -> 272-tiles track
# Total number of obstacles in the track: 7
# Episode:163 Score:547.4169741697339
# Track generation: 1156..1449 -> 293-tiles track
# Total number of obstacles in the track: 5
# Episode:164 Score:211.6438356164427
# Track generation: 1146..1446 -> 300-tiles track
# Total number of obstacles in the track: 6
# Episode:165 Score:448.49498327757993
# Track generation: 1114..1401 -> 287-tiles track
# Total number of obstacles in the track: 8
# Episode:166 Score:553.8461538461441
# Track generation: 1120..1405 -> 285-tiles track
# Total number of obstacles in the track: 8
# Episode:167 Score:551.4084507042153
# Track generation: 1003..1266 -> 263-tiles track
# Total number of obstacles in the track: 8
# Episode:168 Score:590.4580152671666
# Track generation: 1138..1386 -> 248-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1096..1377 -> 281-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1212..1519 -> 307-tiles track
# Total number of obstacles in the track: 8
# Episode:169 Score:520.9150326797285
# Track generation: 1143..1433 -> 290-tiles track
# Total number of obstacles in the track: 6
# Episode:170 Score:592.0415224913424
# Track generation: 1139..1428 -> 289-tiles track
# Total number of obstacles in the track: 9
# Episode:171 Score:500.69444444443656
# Track generation: 1130..1417 -> 287-tiles track
# Total number of obstacles in the track: 8
# Episode:172 Score:492.3076923076856
# Track generation: 1046..1320 -> 274-tiles track
# Total number of obstacles in the track: 8
# Episode:173 Score:676.5567765567662
# Track generation: 1120..1412 -> 292-tiles track
# Total number of obstacles in the track: 10
# Episode:174 Score:594.158075601366
# Track generation: 1207..1522 -> 315-tiles track
# Total number of obstacles in the track: 6
# Episode:175 Score:489.171974522284
# Track generation: 1058..1328 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1245..1558 -> 313-tiles track
# Total number of obstacles in the track: 8
# Episode:176 Score:507.0512820512778
# Track generation: 1107..1388 -> 281-tiles track
# Total number of obstacles in the track: 7
# Episode:177 Score:585.7142857142727
# Track generation: 1153..1445 -> 292-tiles track
# Total number of obstacles in the track: 8
# Episode:178 Score:583.8487972508483
# Track generation: 1116..1399 -> 283-tiles track
# Total number of obstacles in the track: 8
# Episode:179 Score:374.1134751773014
# Track generation: 1203..1508 -> 305-tiles track
# Total number of obstacles in the track: 8
# Episode:180 Score:518.4210526315693
# Track generation: 1203..1508 -> 305-tiles track
# Total number of obstacles in the track: 9
# Episode:181 Score:471.7105263157793
# Track generation: 1104..1384 -> 280-tiles track
# Total number of obstacles in the track: 8
# Episode:182 Score:641.9354838709561
# Track generation: 1131..1418 -> 287-tiles track
# Total number of obstacles in the track: 7
# Episode:183 Score:595.8041958041867
# Track generation: 1100..1379 -> 279-tiles track
# Total number of obstacles in the track: 4
# Episode:184 Score:566.1870503596997
# Track generation: 1185..1486 -> 301-tiles track
# Total number of obstacles in the track: 8
# Episode:185 Score:586.666666666656
# Track generation: 1191..1493 -> 302-tiles track
# Total number of obstacles in the track: 9
# Episode:186 Score:448.00664451826185
# Track generation: 1070..1345 -> 275-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1248..1564 -> 316-tiles track
# Total number of obstacles in the track: 10
# Episode:187 Score:576.1904761904657
# Track generation: 1117..1408 -> 291-tiles track
# Total number of obstacles in the track: 10
# Episode:188 Score:582.7586206896458
# Track generation: 1180..1479 -> 299-tiles track
# Total number of obstacles in the track: 10
# Episode:189 Score:296.30872483221714
# Track generation: 955..1198 -> 243-tiles track
# Total number of obstacles in the track: 3
# Episode:190 Score:767.3553719008161
# Track generation: 1215..1523 -> 308-tiles track
# Total number of obstacles in the track: 8
# Episode:191 Score:292.83387622149775
# Track generation: 1100..1379 -> 279-tiles track
# Total number of obstacles in the track: 9
# Episode:192 Score:676.9784172661736
# Track generation: 1124..1412 -> 288-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1211..1519 -> 308-tiles track
# Total number of obstacles in the track: 9
# Episode:193 Score:433.06188925081244
# Track generation: 1248..1564 -> 316-tiles track
# Total number of obstacles in the track: 8
# Episode:194 Score:465.8730158730101
# Track generation: 1199..1503 -> 304-tiles track
# Total number of obstacles in the track: 9
# Episode:195 Score:533.663366336627
# Track generation: 1170..1466 -> 296-tiles track
# Total number of obstacles in the track: 9
# Episode:196 Score:454.23728813558876
# Track generation: 1145..1444 -> 299-tiles track
# Total number of obstacles in the track: 9
# Episode:197 Score:520.8053691275097
# Track generation: 1247..1563 -> 316-tiles track
# Total number of obstacles in the track: 10
# Episode:198 Score:475.3968253968186
# Track generation: 1209..1515 -> 306-tiles track
# Total number of obstacles in the track: 9
# Episode:199 Score:370.49180327868896
# Track generation: 1256..1574 -> 318-tiles track
# Total number of obstacles in the track: 10
# Episode:200 Score:499.369085173491
# Track generation: 1149..1440 -> 291-tiles track
# Total number of obstacles in the track: 9
# Episode:201 Score:631.0344827586074
# Track generation: 1227..1538 -> 311-tiles track
# Total number of obstacles in the track: 8
# Episode:202 Score:383.8709677419308
# Track generation: 1105..1385 -> 280-tiles track
# Total number of obstacles in the track: 6
# Episode:203 Score:645.5197132616364
# Track generation: 1163..1458 -> 295-tiles track
# Total number of obstacles in the track: 8
# Episode:204 Score:563.2653061224412
# Track generation: 1172..1469 -> 297-tiles track
# Total number of obstacles in the track: 7
# Episode:205 Score:595.9459459459343
# Track generation: 1128..1414 -> 286-tiles track
# Total number of obstacles in the track: 9
# Episode:206 Score:612.2807017543724
# Track generation: 1638..2052 -> 414-tiles track
# Total number of obstacles in the track: 9
# Episode:207 Score:166.34382566586365
# Track generation: 1196..1500 -> 304-tiles track
# Total number of obstacles in the track: 6
# Episode:208 Score:645.8745874587373
# Track generation: 1304..1634 -> 330-tiles track
# Total number of obstacles in the track: 9
# Episode:209 Score:465.34954407293924
# Track generation: 1306..1637 -> 331-tiles track
# Total number of obstacles in the track: 9
# Episode:210 Score:451.5151515151422
# Track generation: 1083..1365 -> 282-tiles track
# Total number of obstacles in the track: 7
# Episode:211 Score:675.800711743762
# Track generation: 1182..1488 -> 306-tiles track
# Total number of obstacles in the track: 6
# Episode:212 Score:637.7049180327782
# Track generation: 1247..1563 -> 316-tiles track
# Total number of obstacles in the track: 6
# Episode:213 Score:453.9682539682443
# Track generation: 1156..1449 -> 293-tiles track
# Total number of obstacles in the track: 10
# Episode:214 Score:521.2328767123188
# Track generation: 1151..1443 -> 292-tiles track
# Total number of obstacles in the track: 9
# Episode:215 Score:662.8865979381306
# Track generation: 1072..1347 -> 275-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1056..1324 -> 268-tiles track
# Total number of obstacles in the track: 9
# Episode:216 Score:470.41198501871713
# Track generation: 1202..1506 -> 304-tiles track
# Total number of obstacles in the track: 6
# Episode:217 Score:358.74587458745845
# Track generation: 1131..1418 -> 287-tiles track
# Total number of obstacles in the track: 7
# Episode:218 Score:500.34965034964443
# Track generation: 1139..1428 -> 289-tiles track
# Total number of obstacles in the track: 9
# Episode:219 Score:495.8333333333229
# Track generation: 1043..1308 -> 265-tiles track
# Total number of obstacles in the track: 7
# Episode:220 Score:538.636363636356
# Track generation: 1201..1505 -> 304-tiles track
# Total number of obstacles in the track: 4
# Episode:221 Score:418.15181518151167
# Track generation: 1400..1754 -> 354-tiles track
# Total number of obstacles in the track: 10
# Episode:222 Score:218.27195467422519
# Track generation: 1302..1631 -> 329-tiles track
# Total number of obstacles in the track: 11
# Episode:223 Score:217.07317073171265
# Track generation: 1119..1403 -> 284-tiles track
# Total number of obstacles in the track: 8
# Episode:224 Score:531.9787985865645
# Track generation: 1289..1615 -> 326-tiles track
# Total number of obstacles in the track: 7
# Episode:225 Score:483.8461538461444
# Track generation: 1175..1473 -> 298-tiles track
# Total number of obstacles in the track: 5
# Episode:226 Score:610.4377104376978
# Track generation: 1027..1290 -> 263-tiles track
# Total number of obstacles in the track: 7
# Episode:227 Score:716.7938931297613
# Track generation: 1043..1310 -> 267-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1297..1625 -> 328-tiles track
# Total number of obstacles in the track: 7
# Episode:228 Score:501.376146788986
# Track generation: 1156..1449 -> 293-tiles track
# Total number of obstacles in the track: 9
# Episode:229 Score:334.931506849316
# Track generation: 1195..1498 -> 303-tiles track
# Total number of obstacles in the track: 8
# Episode:230 Score:479.4701986754871
# Track generation: 1102..1385 -> 283-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1215..1523 -> 308-tiles track
# Total number of obstacles in the track: 10
# Episode:231 Score:496.0912052117183
# Track generation: 1105..1390 -> 285-tiles track
# Total number of obstacles in the track: 5
# Episode:232 Score:430.2816901408362
# Track generation: 1161..1456 -> 295-tiles track
# Total number of obstacles in the track: 10
# Episode:233 Score:235.3741496598569
# Track generation: 1227..1538 -> 311-tiles track
# Total number of obstacles in the track: 9
# Episode:234 Score:87.09677419355137
# Track generation: 1030..1296 -> 266-tiles track
# Total number of obstacles in the track: 8
# Episode:235 Score:688.6792452830074
# Track generation: 1296..1625 -> 329-tiles track
# Total number of obstacles in the track: 10
# Episode:236 Score:524.9999999999911
# Track generation: 1090..1368 -> 278-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1211..1517 -> 306-tiles track
# Total number of obstacles in the track: 6
# Episode:237 Score:568.8524590163835
# Track generation: 1108..1389 -> 281-tiles track
# Total number of obstacles in the track: 8
# Episode:238 Score:574.999999999987
# Track generation: 1019..1284 -> 265-tiles track
# Total number of obstacles in the track: 9
# Episode:239 Score:619.6969696969609
# Track generation: 1206..1515 -> 309-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1125..1414 -> 289-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1175..1473 -> 298-tiles track
# Total number of obstacles in the track: 11
# Episode:240 Score:543.0976430976318
# Track generation: 1036..1301 -> 265-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1195..1498 -> 303-tiles track
# Total number of obstacles in the track: 4
# Episode:241 Score:539.0728476821103
# Track generation: 1124..1409 -> 285-tiles track
# Total number of obstacles in the track: 6
# Episode:242 Score:493.6619718309804
# Track generation: 1128..1412 -> 284-tiles track
# Total number of obstacles in the track: 9
# Episode:243 Score:451.23674911659947
# Track generation: 1167..1463 -> 296-tiles track
# Total number of obstacles in the track: 5
# Episode:244 Score:540.6779661016832
# Track generation: 1103..1383 -> 280-tiles track
# Total number of obstacles in the track: 8
# Episode:245 Score:663.4408602150414
# Track generation: 1156..1449 -> 293-tiles track
# Total number of obstacles in the track: 7
# Episode:246 Score:578.0821917808113
# Track generation: 1050..1317 -> 267-tiles track
# Total number of obstacles in the track: 8
# Episode:247 Score:455.2631578947264
# Track generation: 1003..1258 -> 255-tiles track
# Total number of obstacles in the track: 8
# Episode:248 Score:695.2755905511688
# Track generation: 1172..1469 -> 297-tiles track
# Total number of obstacles in the track: 10
# Episode:249 Score:499.3243243243177
# Track generation: 1312..1644 -> 332-tiles track
# Total number of obstacles in the track: 12
# Episode:250 Score:483.08157099696706
# Track generation: 1134..1421 -> 287-tiles track
# Total number of obstacles in the track: 9
# Episode:251 Score:394.40559440558917
# Track generation: 1020..1279 -> 259-tiles track
# Total number of obstacles in the track: 4
# Episode:252 Score:671.3178294573562
# Track generation: 1037..1305 -> 268-tiles track
# Total number of obstacles in the track: 5
# Episode:253 Score:657.6779026217123
# Track generation: 1099..1378 -> 279-tiles track
# Total number of obstacles in the track: 8
# Episode:254 Score:612.230215827325
# Track generation: 1158..1452 -> 294-tiles track
# Total number of obstacles in the track: 8
# Episode:255 Score:480.204778156984
# Track generation: 1068..1344 -> 276-tiles track
# Total number of obstacles in the track: 8
# Episode:256 Score:551.8181818181681
# Track generation: 1176..1483 -> 307-tiles track
# Total number of obstacles in the track: 11
# Episode:257 Score:514.3790849673109
# Track generation: 1156..1449 -> 293-tiles track
# Total number of obstacles in the track: 9
# Episode:258 Score:341.0958904109491
# Track generation: 1161..1456 -> 295-tiles track
# Total number of obstacles in the track: 8
# Episode:259 Score:305.782312925161
# Track generation: 1045..1317 -> 272-tiles track
# Total number of obstacles in the track: 8
# Episode:260 Score:623.2472324723183
# Track generation: 1349..1690 -> 341-tiles track
# Total number of obstacles in the track: 10
# Episode:261 Score:373.52941176469886
# Track generation: 1176..1474 -> 298-tiles track
# Total number of obstacles in the track: 5
# Episode:262 Score:457.0707070706959
# Track generation: 985..1242 -> 257-tiles track
# Total number of obstacles in the track: 6
# Episode:263 Score:689.0624999999898
# Track generation: 1235..1548 -> 313-tiles track
# Total number of obstacles in the track: 6
# Episode:264 Score:579.4871794871709
# Track generation: 1220..1529 -> 309-tiles track
# Total number of obstacles in the track: 9
# Episode:265 Score:510.38961038960286
# Track generation: 1154..1446 -> 292-tiles track
# Total number of obstacles in the track: 9
# Episode:266 Score:645.7044673539388
# Track generation: 1288..1614 -> 326-tiles track
# Total number of obstacles in the track: 9
# Episode:267 Score:447.6923076922992
# Track generation: 1181..1480 -> 299-tiles track
# Total number of obstacles in the track: 8
# Episode:268 Score:551.0067114093866
# Track generation: 1141..1414 -> 273-tiles track
# Total number of obstacles in the track: 8
# Episode:269 Score:164.70588235294633
# Track generation: 1127..1413 -> 286-tiles track
# Total number of obstacles in the track: 9
# Episode:270 Score:604.3859649122656
# Track generation: 1179..1478 -> 299-tiles track
# Total number of obstacles in the track: 4
# Episode:271 Score:661.7449664429415
# Track generation: 1151..1443 -> 292-tiles track
# Total number of obstacles in the track: 9
# Episode:272 Score:103.95189003436835
# Track generation: 963..1219 -> 256-tiles track
# Total number of obstacles in the track: 8
# Episode:273 Score:629.4117647058686
# Track generation: 1065..1341 -> 276-tiles track
# Total number of obstacles in the track: 7
# Episode:274 Score:696.3636363636235
# Track generation: 1315..1648 -> 333-tiles track
# Total number of obstacles in the track: 8
# Episode:275 Score:309.036144578312
# Track generation: 1135..1423 -> 288-tiles track
# Total number of obstacles in the track: 6
# Episode:276 Score:624.7386759581786
# Track generation: 1090..1367 -> 277-tiles track
# Total number of obstacles in the track: 7
# Episode:277 Score:542.7536231883971
# Track generation: 1101..1380 -> 279-tiles track
# Total number of obstacles in the track: 8
# Episode:278 Score:512.2302158273257
# Track generation: 1199..1503 -> 304-tiles track
# Total number of obstacles in the track: 9
# Episode:279 Score:263.0363036303671
# Track generation: 1059..1330 -> 271-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1136..1424 -> 288-tiles track
# Total number of obstacles in the track: 9
# Episode:280 Score:492.3344947735088
# Track generation: 1153..1445 -> 292-tiles track
# Total number of obstacles in the track: 6
# Episode:281 Score:623.1958762886514
# Track generation: 1213..1524 -> 311-tiles track
# Total number of obstacles in the track: 7
# Episode:282 Score:570.9677419354759
# Track generation: 1035..1301 -> 266-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1218..1526 -> 308-tiles track
# Total number of obstacles in the track: 9
# Episode:283 Score:554.7231270358216
# Track generation: 1099..1378 -> 279-tiles track
# Total number of obstacles in the track: 7
# Episode:284 Score:572.6618705035851
# Track generation: 1011..1268 -> 257-tiles track
# Total number of obstacles in the track: 7
# Episode:285 Score:681.2499999999889
# Track generation: 1299..1628 -> 329-tiles track
# Total number of obstacles in the track: 7
# Episode:286 Score:503.65853658535866
# Track generation: 1092..1369 -> 277-tiles track
# Total number of obstacles in the track: 6
# Episode:287 Score:530.4347826086861
# Track generation: 1134..1430 -> 296-tiles track
# Total number of obstacles in the track: 10
# Episode:288 Score:427.1186440677903
# Track generation: 1148..1439 -> 291-tiles track
# Total number of obstacles in the track: 6
# Episode:289 Score:534.4827586206778
# Track generation: 1092..1373 -> 281-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1183..1483 -> 300-tiles track
# Total number of obstacles in the track: 8
# Episode:290 Score:445.3177257525057
# Track generation: 1192..1494 -> 302-tiles track
# Total number of obstacles in the track: 7
# Episode:291 Score:428.0730897009952
# Track generation: 1151..1443 -> 292-tiles track
# Total number of obstacles in the track: 10
# Episode:292 Score:621.6494845360702
# Track generation: 1315..1648 -> 333-tiles track
# Total number of obstacles in the track: 9
# Episode:293 Score:466.26506024095863
# Track generation: 1027..1288 -> 261-tiles track
# Total number of obstacles in the track: 4
# Episode:294 Score:646.1538461538335
# Track generation: 1148..1439 -> 291-tiles track
# Total number of obstacles in the track: 5
# Episode:295 Score:577.5862068965416
# Track generation: 1076..1349 -> 273-tiles track
# Total number of obstacles in the track: 8
# Episode:296 Score:563.2352941176352
# Track generation: 1279..1603 -> 324-tiles track
# Total number of obstacles in the track: 7
# Episode:297 Score:478.9473684210446
# Track generation: 1094..1372 -> 278-tiles track
# Total number of obstacles in the track: 5
# Episode:298 Score:607.581227436815
# Track generation: 914..1152 -> 238-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1155..1448 -> 293-tiles track
# Total number of obstacles in the track: 7
# Episode:299 Score:154.79452054794623
# Track generation: 1262..1582 -> 320-tiles track
# Total number of obstacles in the track: 9
# Episode:300 Score:386.20689655171657
# Track generation: 1115..1398 -> 283-tiles track
# Total number of obstacles in the track: 9
# Episode:301 Score:442.55319148935155
# Track generation: 1065..1340 -> 275-tiles track
# Total number of obstacles in the track: 9
# Episode:302 Score:586.131386861304
# Track generation: 1148..1439 -> 291-tiles track
# Total number of obstacles in the track: 8
# Episode:303 Score:517.2413793103334
# Track generation: 1099..1378 -> 279-tiles track
# Total number of obstacles in the track: 9
# Episode:304 Score:443.88489208632166
# Track generation: 1079..1358 -> 279-tiles track
# Total number of obstacles in the track: 9
# Episode:305 Score:569.064748201427
# Track generation: 1210..1525 -> 315-tiles track
# Total number of obstacles in the track: 6
# Episode:306 Score:415.6050955413956
# Track generation: 1305..1635 -> 330-tiles track
# Total number of obstacles in the track: 12
# Episode:307 Score:432.2188449848004
# Track generation: 1308..1639 -> 331-tiles track
# Total number of obstacles in the track: 9
# Episode:308 Score:451.51515151514275
# Track generation: 1183..1483 -> 300-tiles track
# Total number of obstacles in the track: 9
# Episode:309 Score:629.0969899665429
# Track generation: 1075..1348 -> 273-tiles track
# Total number of obstacles in the track: 9
# Episode:310 Score:605.8823529411648
# Track generation: 1159..1453 -> 294-tiles track
# Total number of obstacles in the track: 7
# Episode:311 Score:589.419795221828
# Track generation: 1175..1473 -> 298-tiles track
# Total number of obstacles in the track: 9
# Episode:312 Score:604.2087542087407
# Track generation: 1171..1467 -> 296-tiles track
# Total number of obstacles in the track: 5
# Episode:313 Score:619.4915254237173
# Track generation: 1147..1441 -> 294-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1129..1416 -> 287-tiles track
# Total number of obstacles in the track: 6
# Episode:314 Score:445.45454545453714
# Track generation: 1063..1333 -> 270-tiles track
# Total number of obstacles in the track: 10
# Episode:315 Score:419.14498141263607
# Track generation: 1224..1534 -> 310-tiles track
# Total number of obstacles in the track: 11
# Episode:316 Score:359.87055016180284
# Track generation: 1140..1429 -> 289-tiles track
# Total number of obstacles in the track: 8
# Episode:317 Score:604.8611111111012
# Track generation: 1186..1487 -> 301-tiles track
# Total number of obstacles in the track: 4
# Episode:318 Score:333.333333333334
# Track generation: 1128..1414 -> 286-tiles track
# Total number of obstacles in the track: 6
# Episode:319 Score:432.45614035086385
# Track generation: 1317..1650 -> 333-tiles track
# Total number of obstacles in the track: 6
# Episode:320 Score:318.6746987951792
# Track generation: 1229..1547 -> 318-tiles track
# Total number of obstacles in the track: 9
# Episode:321 Score:326.8138801261694
# Track generation: 1143..1433 -> 290-tiles track
# Total number of obstacles in the track: 7
# Episode:322 Score:619.7231833909959
# Track generation: 1124..1409 -> 285-tiles track
# Total number of obstacles in the track: 7
# Episode:323 Score:551.4084507042166
# Track generation: 1268..1589 -> 321-tiles track
# Total number of obstacles in the track: 9
# Episode:324 Score:440.6249999999899
# Track generation: 1149..1440 -> 291-tiles track
# Total number of obstacles in the track: 7
# Episode:325 Score:577.5862068965396
# Track generation: 1135..1423 -> 288-tiles track
# Total number of obstacles in the track: 8
# Episode:326 Score:628.222996515668
# Track generation: 1220..1529 -> 309-tiles track
# Total number of obstacles in the track: 10
# Episode:327 Score:319.4805194805207
# Track generation: 1182..1488 -> 306-tiles track
# Total number of obstacles in the track: 8
# Episode:328 Score:513.114754098352
# Track generation: 1260..1579 -> 319-tiles track
# Total number of obstacles in the track: 8
# Episode:329 Score:438.3647798742076
# Track generation: 1117..1400 -> 283-tiles track
# Total number of obstacles in the track: 6
# Episode:330 Score:509.21985815602426
# Track generation: 1075..1354 -> 279-tiles track
# Total number of obstacles in the track: 6
# Episode:331 Score:655.3956834532239
# Track generation: 1259..1578 -> 319-tiles track
# Total number of obstacles in the track: 9
# Episode:332 Score:456.91823899370183
# Track generation: 1092..1369 -> 277-tiles track
# Total number of obstacles in the track: 7
# Episode:333 Score:555.7971014492674
# Track generation: 1292..1619 -> 327-tiles track
# Total number of obstacles in the track: 9
# Episode:334 Score:577.9141104294397
# Track generation: 1165..1460 -> 295-tiles track
# Total number of obstacles in the track: 8
# Episode:335 Score:549.659863945569
# Track generation: 1189..1490 -> 301-tiles track
# Total number of obstacles in the track: 9
# Episode:336 Score:593.3333333333227
# Track generation: 1279..1603 -> 324-tiles track
# Total number of obstacles in the track: 12
# Episode:337 Score:367.0278637770864
# Track generation: 1216..1524 -> 308-tiles track
# Total number of obstacles in the track: 9
# Episode:338 Score:577.5244299674167
# Track generation: 1149..1441 -> 292-tiles track
# Total number of obstacles in the track: 8
# Episode:339 Score:449.82817869414873
# Track generation: 1049..1316 -> 267-tiles track
# Total number of obstacles in the track: 5
# Episode:340 Score:655.6390977443453
# Track generation: 1143..1433 -> 290-tiles track
# Total number of obstacles in the track: 9
# Episode:341 Score:618.1660899653901
# Track generation: 1223..1533 -> 310-tiles track
# Total number of obstacles in the track: 7
# Episode:342 Score:366.3430420711885
# Track generation: 1125..1421 -> 296-tiles track
# Total number of obstacles in the track: 6
# Episode:343 Score:575.42372881355
# Track generation: 1076..1349 -> 273-tiles track
# Total number of obstacles in the track: 9
# ...
# Total number of obstacles in the track: 10
# Episode:382 Score:471.1864406779579
# Track generation: 1243..1558 -> 315-tiles track
# Total number of obstacles in the track: 9
# Episode:383 Score:345.85987261146033
# Track generation: 1176..1475 -> 299-tiles track
# Total number of obstacles in the track: 8
# Episode:384 Score:514.0939597315336
# Track generation: 1179..1478 -> 299-tiles track
# Total number of obstacles in the track: 8
# Episode:385 Score:289.26174496643677
# Track generation: 1128..1414 -> 286-tiles track
# Total number of obstacles in the track: 9
# Episode:386 Score:330.70175438595476
# Track generation: 1124..1414 -> 290-tiles track
# Total number of obstacles in the track: 10
# Episode:387 Score:460.55363321798643
# Track generation: 1112..1394 -> 282-tiles track
# Total number of obstacles in the track: 7
# Episode:388 Score:241.28113879004076
# Track generation: 996..1255 -> 259-tiles track
# Total number of obstacles in the track: 8
# Episode:389 Score:551.550387596892
# Track generation: 1119..1403 -> 284-tiles track
# Total number of obstacles in the track: 5
# Episode:390 Score:669.2579505300224
# Track generation: 1141..1430 -> 289-tiles track
# Total number of obstacles in the track: 8
# Episode:391 Score:511.11111111110074
# Track generation: 1095..1379 -> 284-tiles track
# Total number of obstacles in the track: 8
# Episode:392 Score:446.64310954063217
# Track generation: 1219..1528 -> 309-tiles track
# Total number of obstacles in the track: 9
# Episode:393 Score:562.9870129870071
# Track generation: 1279..1603 -> 324-tiles track
# Total number of obstacles in the track: 10
# Episode:394 Score:313.4674922600551
# Track generation: 991..1248 -> 257-tiles track
# Total number of obstacles in the track: 5
# Episode:395 Score:653.9062499999876
# Track generation: 1146..1437 -> 291-tiles track
# Total number of obstacles in the track: 11
# Episode:396 Score:543.1034482758517
# Track generation: 1305..1635 -> 330-tiles track
# Total number of obstacles in the track: 7
# Episode:397 Score:374.16413373859086
# Track generation: 1175..1473 -> 298-tiles track
# Total number of obstacles in the track: 9
# Episode:398 Score:416.66666666665753
# Track generation: 1139..1428 -> 289-tiles track
# Total number of obstacles in the track: 4
# Episode:399 Score:556.9444444444323
# Track generation: 1212..1519 -> 307-tiles track
# Total number of obstacles in the track: 6
# Episode:400 Score:498.0392156862638
# Track generation: 1150..1447 -> 297-tiles track
# Total number of obstacles in the track: 7
# Episode:401 Score:295.27027027026
# Track generation: 1159..1453 -> 294-tiles track
# Total number of obstacles in the track: 9
# Episode:402 Score:361.94539249145765
# Track generation: 1260..1580 -> 320-tiles track
# Total number of obstacles in the track: 10
# Episode:403 Score:395.6112852664505
# Track generation: 1248..1564 -> 316-tiles track
# Total number of obstacles in the track: 9
# Episode:404 Score:411.11111111110205
# Track generation: 1067..1338 -> 271-tiles track
# Total number of obstacles in the track: 4
# Episode:405 Score:714.8148148148033
# Track generation: 1260..1582 -> 322-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1021..1284 -> 263-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1196..1499 -> 303-tiles track
# Total number of obstacles in the track: 9
# Episode:406 Score:535.761589403965
# Track generation: 1130..1416 -> 286-tiles track
# Total number of obstacles in the track: 8
# Episode:407 Score:562.2807017543744
# Track generation: 1215..1522 -> 307-tiles track
# Total number of obstacles in the track: 9
# Episode:408 Score:520.9150326797296
# Track generation: 1099..1382 -> 283-tiles track
# Total number of obstacles in the track: 8
# Episode:409 Score:449.2907801418365
# Track generation: 975..1231 -> 256-tiles track
# Total number of obstacles in the track: 6
# Episode:410 Score:572.5490196078292
# Track generation: 1092..1374 -> 282-tiles track
# Total number of obstacles in the track: 6
# Episode:411 Score:625.9786476868219
# Track generation: 1174..1472 -> 298-tiles track
# Total number of obstacles in the track: 10
# Episode:412 Score:570.0336700336576
# Track generation: 1015..1273 -> 258-tiles track
# Total number of obstacles in the track: 5
# Episode:413 Score:724.9027237353962
# Track generation: 1095..1373 -> 278-tiles track
# Total number of obstacles in the track: 7
# Episode:414 Score:632.8519855595572
# Track generation: 994..1247 -> 253-tiles track
# Total number of obstacles in the track: 6
# Episode:415 Score:627.7777777777671
# Track generation: 1129..1415 -> 286-tiles track
# Total number of obstacles in the track: 10
# Episode:416 Score:438.5964912280639
# Track generation: 1193..1495 -> 302-tiles track
# Total number of obstacles in the track: 7
# Episode:417 Score:447.50830564783143
# Track generation: 1170..1467 -> 297-tiles track
# Total number of obstacles in the track: 6
# Episode:418 Score:468.2432432432373
# Track generation: 1147..1440 -> 293-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1111..1393 -> 282-tiles track
# Total number of obstacles in the track: 9
# Episode:419 Score:561.7437722419829
# Track generation: 1084..1359 -> 275-tiles track
# Total number of obstacles in the track: 8
# Episode:420 Score:536.1313868613033
# Track generation: 1180..1479 -> 299-tiles track
# Total number of obstacles in the track: 6
# Episode:421 Score:450.67114093959196
# Track generation: 1036..1307 -> 271-tiles track
# Total number of obstacles in the track: 8
# Episode:422 Score:235.18518518517934
# Track generation: 1091..1372 -> 281-tiles track
# Total number of obstacles in the track: 9
# Episode:423 Score:664.2857142857016
# Track generation: 937..1183 -> 246-tiles track
# Total number of obstacles in the track: 8
# Episode:424 Score:704.0816326530472
# Track generation: 1127..1412 -> 285-tiles track
# Total number of obstacles in the track: 9
# Episode:425 Score:576.0563380281594
# Track generation: 1296..1624 -> 328-tiles track
# Total number of obstacles in the track: 11
# Episode:426 Score:443.2721712538163
# Track generation: 1279..1603 -> 324-tiles track
# Total number of obstacles in the track: 9
# Episode:427 Score:447.98761609906495
# Track generation: 1031..1293 -> 262-tiles track
# Total number of obstacles in the track: 8
# Episode:428 Score:735.2490421455835
# Track generation: 892..1127 -> 235-tiles track
# Total number of obstacles in the track: 6
# Episode:429 Score:619.2307692307555
# Track generation: 1188..1489 -> 301-tiles track
# Total number of obstacles in the track: 8
# Episode:430 Score:516.6666666666534
# Track generation: 1227..1538 -> 311-tiles track
# Total number of obstacles in the track: 11
# Episode:431 Score:338.70967741934476
# Track generation: 1407..1763 -> 356-tiles track
# Total number of obstacles in the track: 10
# Episode:432 Score:145.0704225352159
# Track generation: 1111..1391 -> 280-tiles track
# Total number of obstacles in the track: 5
# Episode:433 Score:660.0358422938947
# Track generation: 1407..1763 -> 356-tiles track
# Total number of obstacles in the track: 11
# Episode:434 Score:283.80281690141175
# Track generation: 1152..1444 -> 292-tiles track
# Total number of obstacles in the track: 9
# Episode:435 Score:482.30240549827437
# Track generation: 1251..1568 -> 317-tiles track
# Total number of obstacles in the track: 9
# Episode:436 Score:334.81012658227934
# Track generation: 1270..1592 -> 322-tiles track
# Total number of obstacles in the track: 6
# Episode:437 Score:420.2492211837896
# Track generation: 1099..1384 -> 285-tiles track
# Total number of obstacles in the track: 6
# Episode:438 Score:625.3521126760446
# Track generation: 1068..1339 -> 271-tiles track
# Total number of obstacles in the track: 7
# Episode:439 Score:609.2592592592484
# Track generation: 1120..1405 -> 285-tiles track
# Total number of obstacles in the track: 8
# Episode:440 Score:546.4788732394309
# Track generation: 1107..1388 -> 281-tiles track
# Total number of obstacles in the track: 6
# Episode:441 Score:607.1428571428446
# Track generation: 1112..1400 -> 288-tiles track
# Total number of obstacles in the track: 10
# Episode:442 Score:441.114982578391
# Track generation: 1152..1450 -> 298-tiles track
# Total number of obstacles in the track: 8
# Episode:443 Score:529.6296296296197
# Track generation: 1116..1399 -> 283-tiles track
# Total number of obstacles in the track: 7
# Episode:444 Score:658.8652482269387
# Track generation: 1104..1384 -> 280-tiles track
# Total number of obstacles in the track: 8
# Episode:445 Score:638.3512544802755
# Track generation: 1167..1463 -> 296-tiles track
# Total number of obstacles in the track: 6
# Episode:446 Score:649.1525423728704
# Track generation: 1100..1379 -> 279-tiles track
# Total number of obstacles in the track: 9
# Episode:447 Score:597.8417266186927
# Track generation: 978..1227 -> 249-tiles track
# Total number of obstacles in the track: 6
# Episode:448 Score:754.8387096774077
# Track generation: 1195..1498 -> 303-tiles track
# Total number of obstacles in the track: 9
# Episode:449 Score:572.1854304635671
# Track generation: 1231..1543 -> 312-tiles track
# Total number of obstacles in the track: 11
# Episode:450 Score:514.147909967836
# Track generation: 1092..1369 -> 277-tiles track
# Total number of obstacles in the track: 5
# Episode:451 Score:700.7246376811494
# Track generation: 1068..1344 -> 276-tiles track
# Total number of obstacles in the track: 5
# Episode:452 Score:638.1818181818043
# Track generation: 1103..1388 -> 285-tiles track
# Total number of obstacles in the track: 9
# Episode:453 Score:625.3521126760448
# Track generation: 1291..1618 -> 327-tiles track
# Total number of obstacles in the track: 8
# Episode:454 Score:257.97546012270317
# Track generation: 1088..1368 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1112..1396 -> 284-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1179..1478 -> 299-tiles track
# Total number of obstacles in the track: 4
# Episode:455 Score:544.6308724832151
# Track generation: 1185..1486 -> 301-tiles track
# Total number of obstacles in the track: 9
# Episode:456 Score:493.3333333333265
# Track generation: 1196..1499 -> 303-tiles track
# Total number of obstacles in the track: 7
# Episode:457 Score:595.3642384105868
# Track generation: 1045..1314 -> 269-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1143..1433 -> 290-tiles track
# Total number of obstacles in the track: 6
# Episode:458 Score:554.3252595155611
# Track generation: 1214..1522 -> 308-tiles track
# Total number of obstacles in the track: 11
# Episode:459 Score:446.0912052117214
# Track generation: 1249..1617 -> 368-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1092..1369 -> 277-tiles track
# Total number of obstacles in the track: 4
# Episode:460 Score:671.7391304347744
# Track generation: 1430..1795 -> 365-tiles track
# Total number of obstacles in the track: 10
# Episode:461 Score:168.68131868132147
# Track generation: 1151..1443 -> 292-tiles track
# Total number of obstacles in the track: 6
# Episode:462 Score:618.2130584192333
# Track generation: 1146..1437 -> 291-tiles track
# Total number of obstacles in the track: 7
# Episode:463 Score:610.3448275861941
# Track generation: 1069..1348 -> 279-tiles track
# Total number of obstacles in the track: 7
# Episode:464 Score:371.9424460431633
# Track generation: 1048..1314 -> 266-tiles track
# Total number of obstacles in the track: 8
# Episode:465 Score:666.037735849046
# Track generation: 1204..1509 -> 305-tiles track
# Total number of obstacles in the track: 10
# Episode:466 Score:446.05263157893785
# Track generation: 1169..1465 -> 296-tiles track
# Total number of obstacles in the track: 10
# Episode:467 Score:416.10169491524454
# Track generation: 1208..1514 -> 306-tiles track
# Total number of obstacles in the track: 8
# Episode:468 Score:296.7213114754053
# Track generation: 1300..1629 -> 329-tiles track
# Total number of obstacles in the track: 9
# Episode:469 Score:195.73170731707822
# Track generation: 1103..1383 -> 280-tiles track
# Total number of obstacles in the track: 7
# Episode:470 Score:627.5985663082323
# Track generation: 1063..1333 -> 270-tiles track
# Total number of obstacles in the track: 6
# Episode:471 Score:584.3866171003596
# Track generation: 1064..1333 -> 269-tiles track
# Total number of obstacles in the track: 9
# Episode:472 Score:573.880597014913
# Track generation: 1091..1376 -> 285-tiles track
# Total number of obstacles in the track: 7
# Episode:473 Score:283.80281690140896
# Track generation: 1331..1668 -> 337-tiles track
# Total number of obstacles in the track: 10
# Episode:474 Score:480.3571428571339
# Track generation: 1315..1648 -> 333-tiles track
# Total number of obstacles in the track: 10
# Episode:475 Score:523.4939759036076
# Track generation: 1117..1400 -> 283-tiles track
# Total number of obstacles in the track: 6
# Episode:476 Score:580.8510638297776
# Track generation: 1186..1487 -> 301-tiles track
# Total number of obstacles in the track: 9
# Episode:477 Score:446.6666666666529
# Track generation: 1092..1375 -> 283-tiles track
# Total number of obstacles in the track: 4
# Episode:478 Score:619.50354609928
# Track generation: 1037..1306 -> 269-tiles track
# Total number of obstacles in the track: 8
# Episode:479 Score:532.8358208955119
# Track generation: 1116..1399 -> 283-tiles track
# Total number of obstacles in the track: 9
# Episode:480 Score:257.80141843971217
# Track generation: 1131..1418 -> 287-tiles track
# Total number of obstacles in the track: 9
# Episode:481 Score:612.2377622377512
# Track generation: 1342..1682 -> 340-tiles track
# Total number of obstacles in the track: 11
# Episode:482 Score:540.1179941002885
# Track generation: 1155..1455 -> 300-tiles track
# Total number of obstacles in the track: 6
# Episode:483 Score:432.274247491631
# Track generation: 1092..1378 -> 286-tiles track
# Total number of obstacles in the track: 8
# Episode:484 Score:612.2807017543728
# Track generation: 1247..1563 -> 316-tiles track
# Total number of obstacles in the track: 7
# Episode:485 Score:557.142857142848
# Track generation: 1135..1423 -> 288-tiles track
# Total number of obstacles in the track: 10
# Episode:486 Score:487.6306620208956
# Track generation: 1184..1484 -> 300-tiles track
# Total number of obstacles in the track: 7
# Episode:487 Score:512.0401337792546
# Track generation: 1186..1487 -> 301-tiles track
# Total number of obstacles in the track: 5
# Episode:488 Score:666.6666666666574
# Track generation: 1083..1358 -> 275-tiles track
# Total number of obstacles in the track: 7
# Episode:489 Score:670.0729927007184
# Track generation: 1047..1313 -> 266-tiles track
# Total number of obstacles in the track: 7
# Episode:490 Score:628.3018867924419
# Track generation: 1112..1394 -> 282-tiles track
# Total number of obstacles in the track: 9
# Episode:491 Score:675.8007117437601
# Track generation: 1034..1297 -> 263-tiles track
# Total number of obstacles in the track: 8
# Episode:492 Score:609.9236641221278
# Track generation: 1224..1534 -> 310-tiles track
# Total number of obstacles in the track: 10
# Episode:493 Score:524.5954692556506
# Track generation: 958..1208 -> 250-tiles track
# Total number of obstacles in the track: 9
# Episode:494 Score:386.3453815260931
# Track generation: 1378..1727 -> 349-tiles track
# Total number of obstacles in the track: 9
# Episode:495 Score:401.72413793102646
# Track generation: 1134..1431 -> 297-tiles track
# Total number of obstacles in the track: 6
# Episode:496 Score:502.7027027026928
# Track generation: 1123..1408 -> 285-tiles track
# Total number of obstacles in the track: 8
# Episode:497 Score:523.2394366197091
# Track generation: 1033..1296 -> 263-tiles track
# Total number of obstacles in the track: 6
# Episode:498 Score:555.7251908396894
# Track generation: 1131..1418 -> 287-tiles track
# Total number of obstacles in the track: 8
# Episode:499 Score:546.8531468531366
# Track generation: 1345..1685 -> 340-tiles track
# Total number of obstacles in the track: 12
# Episode:500 Score:292.6253687315628
# Number of tiles: 188.102
# Time taken: 20.019999999999726
# Ratio: 0.09067024642024649
